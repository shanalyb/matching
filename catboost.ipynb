# %%
import re
import pickle
import pandas as pd
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import f1_score, precision_score, recall_score
from catboost import CatBoostClassifier
from transliterate import translit
import networkx as nx
# from sklearn.metrics.pairwise import cosine_similarity
# from gensim.models.phrases import Phrases, Phraser

# %%
df = pd.read_csv("train.csv", index_col=0)
df.head()
# Out:
#                                     name_1  \
# pair_id
# 1                      Iko Industries Ltd.
# 2                  Apcotex Industries Ltd.
# 3        Rishichem Distributors Pvt., Ltd.
# 4                  Powermax Rubber Factory
# 5                                Tress A/S
#
#                                        name_2  is_duplicate
# pair_id
# 1        Enormous Industrial Trade Pvt., Ltd.             0
# 2         Technocraft Industries (India) Ltd.             0
# 3                                         Dsa             0
# 4                                     Co. One             0
# 5            Longyou Industries Park Zhejiang             0

# %% [markdown]
# ## Feature statistics

# %%
len(set(df.name_1.to_list()))
# Out:
# 17656

# %%
len(set(df.name_2.to_list()))
# Out:
# 17684

# %%
len(set(df.name_1.to_list()) - set(df.name_2.to_list()))
# Out:
# 338

# %% [markdown]
# ## Target statistics

# %%
df['is_duplicate'].value_counts()
# Out:
# 0    494161
# 1      3658
# Name: is_duplicate, dtype: int64

# %% [markdown]
# ## Preprocessing

# %%
# Приведение к нижнему регистру
def lower_str(data, column):
    return data[column].str.lower()

# %%
df['name_1'] = lower_str(df, 'name_1')
df['name_2'] = lower_str(df, 'name_2')

# %%
rus_letters = [
    "а",
    "б",
    "в",
    "г",
    "д",
    "е",
    "ё",
    "ж",
    "з",
    "и",
    "й",
    "к",
    "л",
    "м",
    "н",
    "о",
    "п",
    "р",
    "с",
    "т",
    "у",
    "ф",
    "х",
    "ц",
    "ч",
    "ш",
    "щ",
    "ъ",
    "ы",
    "ь",
    "э",
    "ю",
    "я",
]

# %%
def translit_to_eng(company_name, language_code="ru"):
        if any([i in rus_letters for i in company_name]):
                return translit(company_name, language_code=language_code, reversed=True)
        else:
                return company_name

# %%
df['name_1'] = df['name_1'].apply(lambda x: translit_to_eng(x))
df['name_2'] = df['name_2'].apply(lambda x: translit_to_eng(x))

# %%
y = df['is_duplicate'].values
X = df.drop('is_duplicate', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234, stratify=y)

# %%
name = (X_train['name_1'] + X_train['name_2']).unique()

# %%
tfidf_veczr = TfidfVectorizer(ngram_range=(1,3))    
tf_corpus = tfidf_veczr.fit_transform(name)

# %%
pickle.dump(tfidf_veczr, open("tfidf.pickle", "wb"))

# %%
train_name_1 = tfidf_veczr.transform(X_train['name_1'].apply(lambda x: x).tolist())
train_name_2 = tfidf_veczr.transform(X_train['name_2'].apply(lambda x: x).tolist())
X_train = train_name_1 + train_name_2

# %%
test_name_1 = tfidf_veczr.transform(X_test['name_1'].apply(lambda x: x).tolist())
test_name_2 = tfidf_veczr.transform(X_test['name_2'].apply(lambda x: x).tolist())
X_test = test_name_1 + test_name_2

# %%
X_train
# Out:
# <398255x951979 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5710353 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Model

# %%
model = CatBoostClassifier(
    random_seed=43,
)
model.fit(X_train, y_train)
# Out:
# Learning rate set to 0.132801
# 0:	learn: 0.4129293	total: 536ms	remaining: 8m 55s
# 1:	learn: 0.2583494	total: 1.15s	remaining: 9m 34s
# 2:	learn: 0.1628200	total: 1.65s	remaining: 9m 8s
# 3:	learn: 0.1091222	total: 2.23s	remaining: 9m 14s
# 4:	learn: 0.0783559	total: 2.72s	remaining: 9m
# 5:	learn: 0.0603225	total: 3.15s	remaining: 8m 41s
# 6:	learn: 0.0484237	total: 3.56s	remaining: 8m 25s
# 7:	learn: 0.0416666	total: 3.96s	remaining: 8m 10s
# 8:	learn: 0.0365629	total: 4.35s	remaining: 7m 59s
# 9:	learn: 0.0331784	total: 4.75s	remaining: 7m 50s
# 10:	learn: 0.0304922	total: 5.15s	remaining: 7m 43s
# 11:	learn: 0.0284843	total: 5.54s	remaining: 7m 36s
# 12:	learn: 0.0269928	total: 5.93s	remaining: 7m 30s
# 13:	learn: 0.0259225	total: 6.32s	remaining: 7m 25s
# 14:	learn: 0.0248885	total: 6.72s	remaining: 7m 21s
# 15:	learn: 0.0240866	total: 7.11s	remaining: 7m 17s
# 16:	learn: 0.0233534	total: 7.5s	remaining: 7m 13s
# 17:	learn: 0.0227590	total: 7.88s	remaining: 7m 10s
# 18:	learn: 0.0222268	total: 8.27s	remaining: 7m 7s
# 19:	learn: 0.0216478	total: 8.66s	remaining: 7m 4s
# 20:	learn: 0.0212573	total: 9.06s	remaining: 7m 2s
# 21:	learn: 0.0208723	total: 9.46s	remaining: 7m
# 22:	learn: 0.0204273	total: 9.84s	remaining: 6m 57s
# 23:	learn: 0.0201018	total: 10.2s	remaining: 6m 56s
# 24:	learn: 0.0197443	total: 10.6s	remaining: 6m 54s
# 25:	learn: 0.0194553	total: 11s	remaining: 6m 52s
# 26:	learn: 0.0191870	total: 11.4s	remaining: 6m 51s
# 27:	learn: 0.0189331	total: 11.8s	remaining: 6m 51s
# 28:	learn: 0.0186902	total: 12.3s	remaining: 6m 50s
# 29:	learn: 0.0184594	total: 12.7s	remaining: 6m 49s
# 30:	learn: 0.0182418	total: 13.1s	remaining: 6m 48s
# 31:	learn: 0.0180371	total: 13.5s	remaining: 6m 47s
# 32:	learn: 0.0178291	total: 13.9s	remaining: 6m 46s
# 33:	learn: 0.0175780	total: 14.2s	remaining: 6m 44s
# 34:	learn: 0.0174141	total: 14.6s	remaining: 6m 43s
# 35:	learn: 0.0172481	total: 15.1s	remaining: 6m 43s
# 36:	learn: 0.0170699	total: 15.5s	remaining: 6m 42s
# 37:	learn: 0.0168564	total: 15.8s	remaining: 6m 41s
# 38:	learn: 0.0167248	total: 16.2s	remaining: 6m 40s
# 39:	learn: 0.0165831	total: 16.6s	remaining: 6m 39s
# 40:	learn: 0.0164293	total: 17s	remaining: 6m 38s
# 41:	learn: 0.0162921	total: 17.4s	remaining: 6m 37s
# 42:	learn: 0.0161726	total: 17.8s	remaining: 6m 36s
# 43:	learn: 0.0160625	total: 18.2s	remaining: 6m 36s
# 44:	learn: 0.0159351	total: 18.6s	remaining: 6m 35s
# 45:	learn: 0.0158291	total: 19s	remaining: 6m 34s
# 46:	learn: 0.0157297	total: 19.4s	remaining: 6m 33s
# 47:	learn: 0.0156371	total: 19.8s	remaining: 6m 32s
# 48:	learn: 0.0155063	total: 20.2s	remaining: 6m 31s
# 49:	learn: 0.0154004	total: 20.6s	remaining: 6m 30s
# 50:	learn: 0.0153203	total: 21s	remaining: 6m 30s
# 51:	learn: 0.0151648	total: 21.4s	remaining: 6m 29s
# 52:	learn: 0.0150072	total: 21.7s	remaining: 6m 28s
# 53:	learn: 0.0148236	total: 22.1s	remaining: 6m 27s
# 54:	learn: 0.0147211	total: 22.5s	remaining: 6m 27s
# 55:	learn: 0.0146254	total: 22.9s	remaining: 6m 26s
# 56:	learn: 0.0145480	total: 23.3s	remaining: 6m 25s
# 57:	learn: 0.0144634	total: 23.7s	remaining: 6m 24s
# 58:	learn: 0.0143909	total: 24.1s	remaining: 6m 24s
# 59:	learn: 0.0142842	total: 24.5s	remaining: 6m 23s
# 60:	learn: 0.0141458	total: 24.9s	remaining: 6m 22s
# 61:	learn: 0.0140687	total: 25.3s	remaining: 6m 22s
# 62:	learn: 0.0140050	total: 25.7s	remaining: 6m 21s
# 63:	learn: 0.0138776	total: 26s	remaining: 6m 20s
# 64:	learn: 0.0138031	total: 26.4s	remaining: 6m 20s
# 65:	learn: 0.0137382	total: 26.8s	remaining: 6m 19s
# 66:	learn: 0.0136867	total: 27.2s	remaining: 6m 18s
# 67:	learn: 0.0135582	total: 27.6s	remaining: 6m 18s
# 68:	learn: 0.0134290	total: 28s	remaining: 6m 17s
# 69:	learn: 0.0133824	total: 28.4s	remaining: 6m 17s
# 70:	learn: 0.0133346	total: 28.8s	remaining: 6m 16s
# 71:	learn: 0.0132820	total: 29.2s	remaining: 6m 16s
# 72:	learn: 0.0132302	total: 29.6s	remaining: 6m 15s
# 73:	learn: 0.0131788	total: 30s	remaining: 6m 14s
# 74:	learn: 0.0131371	total: 30.3s	remaining: 6m 14s
# 75:	learn: 0.0130742	total: 30.7s	remaining: 6m 13s
# 76:	learn: 0.0130059	total: 31.1s	remaining: 6m 13s
# 77:	learn: 0.0129614	total: 31.5s	remaining: 6m 12s
# 78:	learn: 0.0129211	total: 31.9s	remaining: 6m 11s
# 79:	learn: 0.0128850	total: 32.3s	remaining: 6m 11s
# 80:	learn: 0.0128446	total: 32.7s	remaining: 6m 10s
# 81:	learn: 0.0127550	total: 33.1s	remaining: 6m 10s
# 82:	learn: 0.0126040	total: 33.5s	remaining: 6m 9s
# 83:	learn: 0.0125240	total: 33.9s	remaining: 6m 9s
# 84:	learn: 0.0124879	total: 34.2s	remaining: 6m 8s
# 85:	learn: 0.0124050	total: 34.6s	remaining: 6m 8s
# 86:	learn: 0.0123757	total: 35s	remaining: 6m 7s
# 87:	learn: 0.0123325	total: 35.4s	remaining: 6m 7s
# 88:	learn: 0.0122934	total: 35.8s	remaining: 6m 6s
# 89:	learn: 0.0122670	total: 36.2s	remaining: 6m 6s
# 90:	learn: 0.0122286	total: 36.6s	remaining: 6m 5s
# 91:	learn: 0.0121704	total: 37s	remaining: 6m 5s
# 92:	learn: 0.0121369	total: 37.4s	remaining: 6m 4s
# 93:	learn: 0.0120959	total: 37.8s	remaining: 6m 4s
# 94:	learn: 0.0120578	total: 38.2s	remaining: 6m 3s
# 95:	learn: 0.0120141	total: 38.6s	remaining: 6m 3s
# 96:	learn: 0.0119856	total: 38.9s	remaining: 6m 2s
# 97:	learn: 0.0119521	total: 39.3s	remaining: 6m 2s
# 98:	learn: 0.0119245	total: 39.7s	remaining: 6m 1s
# 99:	learn: 0.0118979	total: 40.1s	remaining: 6m
# 100:	learn: 0.0118105	total: 40.5s	remaining: 6m
# 101:	learn: 0.0117381	total: 40.9s	remaining: 5m 59s
# 102:	learn: 0.0116818	total: 41.3s	remaining: 5m 59s
# 103:	learn: 0.0116559	total: 41.7s	remaining: 5m 58s
# 104:	learn: 0.0116284	total: 42.1s	remaining: 5m 58s
# 105:	learn: 0.0115996	total: 42.4s	remaining: 5m 57s
# 106:	learn: 0.0115786	total: 42.8s	remaining: 5m 57s
# 107:	learn: 0.0114575	total: 43.2s	remaining: 5m 56s
# 108:	learn: 0.0113376	total: 43.6s	remaining: 5m 56s
# 109:	learn: 0.0113050	total: 44s	remaining: 5m 56s
# 110:	learn: 0.0112574	total: 44.4s	remaining: 5m 55s
# 111:	learn: 0.0112340	total: 44.8s	remaining: 5m 55s
# 112:	learn: 0.0112142	total: 45.2s	remaining: 5m 54s
# 113:	learn: 0.0111874	total: 45.6s	remaining: 5m 54s
# 114:	learn: 0.0111275	total: 46s	remaining: 5m 54s
# 115:	learn: 0.0111050	total: 46.4s	remaining: 5m 53s
# 116:	learn: 0.0110830	total: 46.8s	remaining: 5m 52s
# 117:	learn: 0.0110348	total: 47.2s	remaining: 5m 52s
# 118:	learn: 0.0110190	total: 47.6s	remaining: 5m 52s
# 119:	learn: 0.0109603	total: 48s	remaining: 5m 51s
# 120:	learn: 0.0109422	total: 48.4s	remaining: 5m 51s
# 121:	learn: 0.0109198	total: 48.8s	remaining: 5m 51s
# 122:	learn: 0.0108556	total: 49.2s	remaining: 5m 50s
# 123:	learn: 0.0108255	total: 49.6s	remaining: 5m 50s
# 124:	learn: 0.0107925	total: 50s	remaining: 5m 49s
# 125:	learn: 0.0107743	total: 50.4s	remaining: 5m 49s
# 126:	learn: 0.0107481	total: 50.8s	remaining: 5m 48s
# 127:	learn: 0.0107320	total: 51.1s	remaining: 5m 48s
# 128:	learn: 0.0107095	total: 51.5s	remaining: 5m 47s
# 129:	learn: 0.0106880	total: 51.9s	remaining: 5m 47s
# 130:	learn: 0.0106340	total: 52.3s	remaining: 5m 46s
# 131:	learn: 0.0106181	total: 52.7s	remaining: 5m 46s
# 132:	learn: 0.0105913	total: 53.1s	remaining: 5m 46s
# 133:	learn: 0.0105692	total: 53.5s	remaining: 5m 45s
# 134:	learn: 0.0105472	total: 53.9s	remaining: 5m 45s
# 135:	learn: 0.0105042	total: 54.3s	remaining: 5m 44s
# 136:	learn: 0.0104816	total: 54.7s	remaining: 5m 44s
# 137:	learn: 0.0104613	total: 55.1s	remaining: 5m 43s
# 138:	learn: 0.0104359	total: 55.5s	remaining: 5m 43s
# 139:	learn: 0.0104152	total: 55.9s	remaining: 5m 43s
# 140:	learn: 0.0103945	total: 56.3s	remaining: 5m 42s
# 141:	learn: 0.0103739	total: 56.6s	remaining: 5m 42s
# 142:	learn: 0.0103532	total: 57s	remaining: 5m 41s
# 143:	learn: 0.0103001	total: 57.4s	remaining: 5m 41s
# 144:	learn: 0.0102803	total: 57.8s	remaining: 5m 41s
# 145:	learn: 0.0102628	total: 58.2s	remaining: 5m 40s
# 146:	learn: 0.0102435	total: 58.6s	remaining: 5m 40s
# 147:	learn: 0.0102248	total: 59s	remaining: 5m 39s
# 148:	learn: 0.0102008	total: 59.4s	remaining: 5m 39s
# 149:	learn: 0.0101819	total: 59.8s	remaining: 5m 38s
# 150:	learn: 0.0101627	total: 1m	remaining: 5m 38s
# 151:	learn: 0.0101441	total: 1m	remaining: 5m 37s
# 152:	learn: 0.0101296	total: 1m	remaining: 5m 37s
# 153:	learn: 0.0101125	total: 1m 1s	remaining: 5m 37s
# 154:	learn: 0.0100950	total: 1m 1s	remaining: 5m 36s
# 155:	learn: 0.0100779	total: 1m 2s	remaining: 5m 36s
# 156:	learn: 0.0100561	total: 1m 2s	remaining: 5m 35s
# 157:	learn: 0.0100388	total: 1m 2s	remaining: 5m 35s
# 158:	learn: 0.0100215	total: 1m 3s	remaining: 5m 35s
# 159:	learn: 0.0100053	total: 1m 3s	remaining: 5m 34s
# 160:	learn: 0.0099881	total: 1m 4s	remaining: 5m 34s
# 161:	learn: 0.0099725	total: 1m 4s	remaining: 5m 33s
# 162:	learn: 0.0099570	total: 1m 4s	remaining: 5m 33s
# 163:	learn: 0.0099415	total: 1m 5s	remaining: 5m 33s
# 164:	learn: 0.0099257	total: 1m 5s	remaining: 5m 32s
# 165:	learn: 0.0099094	total: 1m 6s	remaining: 5m 32s
# 166:	learn: 0.0098944	total: 1m 6s	remaining: 5m 31s
# 167:	learn: 0.0098475	total: 1m 6s	remaining: 5m 31s
# 168:	learn: 0.0098350	total: 1m 7s	remaining: 5m 30s
# 169:	learn: 0.0098217	total: 1m 7s	remaining: 5m 30s
# 170:	learn: 0.0098020	total: 1m 8s	remaining: 5m 30s
# 171:	learn: 0.0097893	total: 1m 8s	remaining: 5m 29s
# 172:	learn: 0.0097753	total: 1m 8s	remaining: 5m 29s
# 173:	learn: 0.0097372	total: 1m 9s	remaining: 5m 28s
# 174:	learn: 0.0097208	total: 1m 9s	remaining: 5m 28s
# 175:	learn: 0.0097079	total: 1m 10s	remaining: 5m 28s
# 176:	learn: 0.0096905	total: 1m 10s	remaining: 5m 27s
# 177:	learn: 0.0096535	total: 1m 10s	remaining: 5m 27s
# 178:	learn: 0.0096432	total: 1m 11s	remaining: 5m 26s
# 179:	learn: 0.0096050	total: 1m 11s	remaining: 5m 26s
# 180:	learn: 0.0095890	total: 1m 12s	remaining: 5m 26s
# 181:	learn: 0.0095788	total: 1m 12s	remaining: 5m 26s
# 182:	learn: 0.0095679	total: 1m 13s	remaining: 5m 26s
# 183:	learn: 0.0095527	total: 1m 13s	remaining: 5m 25s
# 184:	learn: 0.0095412	total: 1m 13s	remaining: 5m 25s
# 185:	learn: 0.0095290	total: 1m 14s	remaining: 5m 24s
# 186:	learn: 0.0094851	total: 1m 14s	remaining: 5m 24s
# 187:	learn: 0.0094691	total: 1m 15s	remaining: 5m 24s
# 188:	learn: 0.0094597	total: 1m 15s	remaining: 5m 23s
# 189:	learn: 0.0094440	total: 1m 15s	remaining: 5m 23s
# 190:	learn: 0.0094303	total: 1m 16s	remaining: 5m 22s
# 191:	learn: 0.0093872	total: 1m 16s	remaining: 5m 22s
# 192:	learn: 0.0093779	total: 1m 17s	remaining: 5m 22s
# 193:	learn: 0.0093690	total: 1m 17s	remaining: 5m 21s
# 194:	learn: 0.0093517	total: 1m 17s	remaining: 5m 21s
# 195:	learn: 0.0093431	total: 1m 18s	remaining: 5m 20s
# 196:	learn: 0.0093334	total: 1m 18s	remaining: 5m 20s
# 197:	learn: 0.0093188	total: 1m 19s	remaining: 5m 20s
# 198:	learn: 0.0093070	total: 1m 19s	remaining: 5m 19s
# 199:	learn: 0.0092981	total: 1m 19s	remaining: 5m 19s
# 200:	learn: 0.0092496	total: 1m 20s	remaining: 5m 18s
# 201:	learn: 0.0091847	total: 1m 20s	remaining: 5m 18s
# 202:	learn: 0.0091714	total: 1m 21s	remaining: 5m 18s
# 203:	learn: 0.0091259	total: 1m 21s	remaining: 5m 17s
# 204:	learn: 0.0091116	total: 1m 21s	remaining: 5m 17s
# 205:	learn: 0.0091032	total: 1m 22s	remaining: 5m 16s
# 206:	learn: 0.0090438	total: 1m 22s	remaining: 5m 16s
# 207:	learn: 0.0090300	total: 1m 23s	remaining: 5m 16s
# 208:	learn: 0.0090245	total: 1m 23s	remaining: 5m 15s
# 209:	learn: 0.0090116	total: 1m 23s	remaining: 5m 15s
# 210:	learn: 0.0090027	total: 1m 24s	remaining: 5m 14s
# 211:	learn: 0.0089905	total: 1m 24s	remaining: 5m 14s
# 212:	learn: 0.0089661	total: 1m 24s	remaining: 5m 14s
# 213:	learn: 0.0089537	total: 1m 25s	remaining: 5m 13s
# 214:	learn: 0.0089464	total: 1m 25s	remaining: 5m 13s
# 215:	learn: 0.0089128	total: 1m 26s	remaining: 5m 12s
# 216:	learn: 0.0089038	total: 1m 26s	remaining: 5m 12s
# 217:	learn: 0.0088561	total: 1m 26s	remaining: 5m 12s
# 218:	learn: 0.0088430	total: 1m 27s	remaining: 5m 11s
# 219:	learn: 0.0088338	total: 1m 27s	remaining: 5m 11s
# 220:	learn: 0.0088256	total: 1m 28s	remaining: 5m 11s
# 221:	learn: 0.0088193	total: 1m 28s	remaining: 5m 10s
# 222:	learn: 0.0087809	total: 1m 29s	remaining: 5m 10s
# 223:	learn: 0.0087432	total: 1m 29s	remaining: 5m 9s
# 224:	learn: 0.0087120	total: 1m 29s	remaining: 5m 9s
# 225:	learn: 0.0086976	total: 1m 30s	remaining: 5m 8s
# 226:	learn: 0.0086851	total: 1m 30s	remaining: 5m 8s
# 227:	learn: 0.0086784	total: 1m 30s	remaining: 5m 8s
# 228:	learn: 0.0086720	total: 1m 31s	remaining: 5m 7s
# 229:	learn: 0.0086634	total: 1m 31s	remaining: 5m 7s
# 230:	learn: 0.0086367	total: 1m 32s	remaining: 5m 6s
# 231:	learn: 0.0086004	total: 1m 32s	remaining: 5m 6s
# 232:	learn: 0.0085642	total: 1m 32s	remaining: 5m 6s
# 233:	learn: 0.0085589	total: 1m 33s	remaining: 5m 5s
# 234:	learn: 0.0085161	total: 1m 33s	remaining: 5m 5s
# 235:	learn: 0.0084930	total: 1m 34s	remaining: 5m 4s
# 236:	learn: 0.0084728	total: 1m 34s	remaining: 5m 4s
# 237:	learn: 0.0084531	total: 1m 34s	remaining: 5m 4s
# 238:	learn: 0.0084222	total: 1m 35s	remaining: 5m 3s
# 239:	learn: 0.0084118	total: 1m 35s	remaining: 5m 3s
# 240:	learn: 0.0083690	total: 1m 36s	remaining: 5m 2s
# 241:	learn: 0.0083394	total: 1m 36s	remaining: 5m 2s
# 242:	learn: 0.0083245	total: 1m 36s	remaining: 5m 2s
# 243:	learn: 0.0083197	total: 1m 37s	remaining: 5m 1s
# 244:	learn: 0.0082845	total: 1m 37s	remaining: 5m 1s
# 245:	learn: 0.0082748	total: 1m 38s	remaining: 5m
# 246:	learn: 0.0082654	total: 1m 38s	remaining: 5m
# 247:	learn: 0.0082596	total: 1m 38s	remaining: 5m
# 248:	learn: 0.0082547	total: 1m 39s	remaining: 4m 59s
# 249:	learn: 0.0082450	total: 1m 39s	remaining: 4m 59s
# 250:	learn: 0.0082396	total: 1m 40s	remaining: 4m 58s
# 251:	learn: 0.0082342	total: 1m 40s	remaining: 4m 58s
# 252:	learn: 0.0082104	total: 1m 40s	remaining: 4m 57s
# 253:	learn: 0.0081919	total: 1m 41s	remaining: 4m 57s
# 254:	learn: 0.0081862	total: 1m 41s	remaining: 4m 57s
# 255:	learn: 0.0081798	total: 1m 42s	remaining: 4m 56s
# 256:	learn: 0.0081542	total: 1m 42s	remaining: 4m 56s
# 257:	learn: 0.0081433	total: 1m 42s	remaining: 4m 55s
# 258:	learn: 0.0081370	total: 1m 43s	remaining: 4m 55s
# 259:	learn: 0.0081295	total: 1m 43s	remaining: 4m 55s
# 260:	learn: 0.0081231	total: 1m 44s	remaining: 4m 54s
# 261:	learn: 0.0081170	total: 1m 44s	remaining: 4m 54s
# 262:	learn: 0.0080798	total: 1m 44s	remaining: 4m 53s
# 263:	learn: 0.0080735	total: 1m 45s	remaining: 4m 53s
# 264:	learn: 0.0080674	total: 1m 45s	remaining: 4m 53s
# 265:	learn: 0.0080350	total: 1m 46s	remaining: 4m 52s
# 266:	learn: 0.0080289	total: 1m 46s	remaining: 4m 52s
# 267:	learn: 0.0080228	total: 1m 46s	remaining: 4m 51s
# 268:	learn: 0.0080117	total: 1m 47s	remaining: 4m 51s
# 269:	learn: 0.0080055	total: 1m 47s	remaining: 4m 51s
# 270:	learn: 0.0079991	total: 1m 48s	remaining: 4m 50s
# 271:	learn: 0.0079929	total: 1m 48s	remaining: 4m 50s
# 272:	learn: 0.0079747	total: 1m 48s	remaining: 4m 50s
# 273:	learn: 0.0079645	total: 1m 49s	remaining: 4m 49s
# 274:	learn: 0.0079580	total: 1m 49s	remaining: 4m 49s
# 275:	learn: 0.0079519	total: 1m 50s	remaining: 4m 48s
# 276:	learn: 0.0079455	total: 1m 50s	remaining: 4m 48s
# 277:	learn: 0.0079394	total: 1m 50s	remaining: 4m 48s
# 278:	learn: 0.0079333	total: 1m 51s	remaining: 4m 47s
# 279:	learn: 0.0079271	total: 1m 51s	remaining: 4m 47s
# 280:	learn: 0.0079207	total: 1m 52s	remaining: 4m 46s
# 281:	learn: 0.0079105	total: 1m 52s	remaining: 4m 46s
# 282:	learn: 0.0079042	total: 1m 52s	remaining: 4m 45s
# 283:	learn: 0.0078980	total: 1m 53s	remaining: 4m 45s
# 284:	learn: 0.0078892	total: 1m 53s	remaining: 4m 45s
# 285:	learn: 0.0078787	total: 1m 54s	remaining: 4m 44s
# 286:	learn: 0.0078725	total: 1m 54s	remaining: 4m 44s
# 287:	learn: 0.0078659	total: 1m 54s	remaining: 4m 43s
# 288:	learn: 0.0078596	total: 1m 55s	remaining: 4m 43s
# 289:	learn: 0.0078529	total: 1m 55s	remaining: 4m 43s
# 290:	learn: 0.0078467	total: 1m 56s	remaining: 4m 42s
# 291:	learn: 0.0078404	total: 1m 56s	remaining: 4m 42s
# 292:	learn: 0.0078341	total: 1m 56s	remaining: 4m 41s
# 293:	learn: 0.0078058	total: 1m 57s	remaining: 4m 41s
# 294:	learn: 0.0077997	total: 1m 57s	remaining: 4m 41s
# 295:	learn: 0.0077894	total: 1m 58s	remaining: 4m 41s
# 296:	learn: 0.0077835	total: 1m 58s	remaining: 4m 40s
# 297:	learn: 0.0077769	total: 1m 59s	remaining: 4m 40s
# 298:	learn: 0.0077705	total: 1m 59s	remaining: 4m 40s
# 299:	learn: 0.0077642	total: 1m 59s	remaining: 4m 39s
# 300:	learn: 0.0077581	total: 2m	remaining: 4m 39s
# 301:	learn: 0.0077522	total: 2m	remaining: 4m 39s
# 302:	learn: 0.0077461	total: 2m 1s	remaining: 4m 38s
# 303:	learn: 0.0077395	total: 2m 1s	remaining: 4m 38s
# 304:	learn: 0.0077333	total: 2m 2s	remaining: 4m 38s
# 305:	learn: 0.0076800	total: 2m 2s	remaining: 4m 37s
# 306:	learn: 0.0076729	total: 2m 2s	remaining: 4m 37s
# 307:	learn: 0.0076659	total: 2m 3s	remaining: 4m 37s
# 308:	learn: 0.0076589	total: 2m 3s	remaining: 4m 36s
# 309:	learn: 0.0076522	total: 2m 4s	remaining: 4m 36s
# 310:	learn: 0.0076453	total: 2m 4s	remaining: 4m 36s
# 311:	learn: 0.0076432	total: 2m 5s	remaining: 4m 35s
# 312:	learn: 0.0076366	total: 2m 5s	remaining: 4m 35s
# 313:	learn: 0.0076302	total: 2m 5s	remaining: 4m 35s
# 314:	learn: 0.0076237	total: 2m 6s	remaining: 4m 34s
# 315:	learn: 0.0076172	total: 2m 7s	remaining: 4m 34s
# 316:	learn: 0.0076109	total: 2m 7s	remaining: 4m 34s
# 317:	learn: 0.0076046	total: 2m 8s	remaining: 4m 34s
# 318:	learn: 0.0075984	total: 2m 8s	remaining: 4m 34s
# 319:	learn: 0.0075922	total: 2m 9s	remaining: 4m 34s
# 320:	learn: 0.0075852	total: 2m 9s	remaining: 4m 34s
# 321:	learn: 0.0075792	total: 2m 10s	remaining: 4m 33s
# 322:	learn: 0.0075730	total: 2m 10s	remaining: 4m 33s
# 323:	learn: 0.0075669	total: 2m 10s	remaining: 4m 33s
# 324:	learn: 0.0075608	total: 2m 11s	remaining: 4m 32s
# 325:	learn: 0.0075536	total: 2m 11s	remaining: 4m 32s
# 326:	learn: 0.0075474	total: 2m 12s	remaining: 4m 32s
# 327:	learn: 0.0075407	total: 2m 12s	remaining: 4m 31s
# 328:	learn: 0.0075159	total: 2m 13s	remaining: 4m 31s
# 329:	learn: 0.0075098	total: 2m 13s	remaining: 4m 31s
# 330:	learn: 0.0075040	total: 2m 14s	remaining: 4m 30s
# 331:	learn: 0.0074982	total: 2m 14s	remaining: 4m 30s
# 332:	learn: 0.0074925	total: 2m 14s	remaining: 4m 30s
# 333:	learn: 0.0074866	total: 2m 15s	remaining: 4m 29s
# 334:	learn: 0.0074810	total: 2m 15s	remaining: 4m 29s
# 335:	learn: 0.0074749	total: 2m 16s	remaining: 4m 29s
# 336:	learn: 0.0074692	total: 2m 16s	remaining: 4m 28s
# 337:	learn: 0.0074635	total: 2m 16s	remaining: 4m 28s
# 338:	learn: 0.0074577	total: 2m 17s	remaining: 4m 27s
# 339:	learn: 0.0074519	total: 2m 17s	remaining: 4m 27s
# 340:	learn: 0.0074461	total: 2m 18s	remaining: 4m 27s
# 341:	learn: 0.0074338	total: 2m 18s	remaining: 4m 26s
# 342:	learn: 0.0074276	total: 2m 19s	remaining: 4m 26s
# 343:	learn: 0.0074056	total: 2m 19s	remaining: 4m 26s
# 344:	learn: 0.0073996	total: 2m 20s	remaining: 4m 26s
# 345:	learn: 0.0073940	total: 2m 20s	remaining: 4m 25s
# 346:	learn: 0.0073676	total: 2m 21s	remaining: 4m 25s
# 347:	learn: 0.0073621	total: 2m 21s	remaining: 4m 25s
# 348:	learn: 0.0073566	total: 2m 21s	remaining: 4m 24s
# 349:	learn: 0.0073503	total: 2m 22s	remaining: 4m 24s
# 350:	learn: 0.0073446	total: 2m 22s	remaining: 4m 24s
# 351:	learn: 0.0073390	total: 2m 23s	remaining: 4m 23s
# 352:	learn: 0.0073336	total: 2m 23s	remaining: 4m 23s
# 353:	learn: 0.0073279	total: 2m 24s	remaining: 4m 23s
# 354:	learn: 0.0073179	total: 2m 25s	remaining: 4m 23s
# 355:	learn: 0.0073125	total: 2m 25s	remaining: 4m 23s
# 356:	learn: 0.0073070	total: 2m 26s	remaining: 4m 23s
# 357:	learn: 0.0073009	total: 2m 26s	remaining: 4m 22s
# 358:	learn: 0.0072954	total: 2m 27s	remaining: 4m 22s
# 359:	learn: 0.0072900	total: 2m 27s	remaining: 4m 22s
# 360:	learn: 0.0072839	total: 2m 28s	remaining: 4m 22s
# 361:	learn: 0.0072783	total: 2m 28s	remaining: 4m 22s
# 362:	learn: 0.0072729	total: 2m 29s	remaining: 4m 22s
# 363:	learn: 0.0072675	total: 2m 29s	remaining: 4m 21s
# 364:	learn: 0.0072622	total: 2m 30s	remaining: 4m 21s
# 365:	learn: 0.0072569	total: 2m 30s	remaining: 4m 21s
# 366:	learn: 0.0072517	total: 2m 31s	remaining: 4m 21s
# 367:	learn: 0.0072465	total: 2m 32s	remaining: 4m 21s
# 368:	learn: 0.0072412	total: 2m 32s	remaining: 4m 20s
# 369:	learn: 0.0072344	total: 2m 33s	remaining: 4m 20s
# 370:	learn: 0.0072292	total: 2m 33s	remaining: 4m 20s
# 371:	learn: 0.0072240	total: 2m 34s	remaining: 4m 20s
# 372:	learn: 0.0072188	total: 2m 34s	remaining: 4m 19s
# 373:	learn: 0.0072136	total: 2m 35s	remaining: 4m 19s
# 374:	learn: 0.0072063	total: 2m 35s	remaining: 4m 19s
# 375:	learn: 0.0071976	total: 2m 36s	remaining: 4m 19s
# 376:	learn: 0.0071925	total: 2m 36s	remaining: 4m 19s
# 377:	learn: 0.0071875	total: 2m 37s	remaining: 4m 18s
# 378:	learn: 0.0071820	total: 2m 37s	remaining: 4m 18s
# 379:	learn: 0.0071770	total: 2m 38s	remaining: 4m 18s
# 380:	learn: 0.0071717	total: 2m 38s	remaining: 4m 18s
# 381:	learn: 0.0071667	total: 2m 39s	remaining: 4m 18s
# 382:	learn: 0.0071618	total: 2m 40s	remaining: 4m 17s
# 383:	learn: 0.0071568	total: 2m 40s	remaining: 4m 17s
# 384:	learn: 0.0071519	total: 2m 41s	remaining: 4m 17s
# 385:	learn: 0.0071470	total: 2m 41s	remaining: 4m 17s
# 386:	learn: 0.0071421	total: 2m 42s	remaining: 4m 17s
# 387:	learn: 0.0071372	total: 2m 42s	remaining: 4m 16s
# 388:	learn: 0.0071314	total: 2m 43s	remaining: 4m 16s
# 389:	learn: 0.0070918	total: 2m 43s	remaining: 4m 16s
# 390:	learn: 0.0070867	total: 2m 44s	remaining: 4m 16s
# 391:	learn: 0.0070814	total: 2m 45s	remaining: 4m 16s
# 392:	learn: 0.0070767	total: 2m 45s	remaining: 4m 15s
# 393:	learn: 0.0070717	total: 2m 46s	remaining: 4m 15s
# 394:	learn: 0.0070702	total: 2m 46s	remaining: 4m 15s
# 395:	learn: 0.0070654	total: 2m 47s	remaining: 4m 15s
# 396:	learn: 0.0070402	total: 2m 47s	remaining: 4m 15s
# 397:	learn: 0.0070355	total: 2m 48s	remaining: 4m 14s
# 398:	learn: 0.0070309	total: 2m 49s	remaining: 4m 14s
# 399:	learn: 0.0070262	total: 2m 49s	remaining: 4m 14s
# 400:	learn: 0.0070216	total: 2m 50s	remaining: 4m 14s
# 401:	learn: 0.0070169	total: 2m 50s	remaining: 4m 13s
# 402:	learn: 0.0070123	total: 2m 51s	remaining: 4m 13s
# 403:	learn: 0.0070077	total: 2m 51s	remaining: 4m 13s
# 404:	learn: 0.0070032	total: 2m 52s	remaining: 4m 13s
# 405:	learn: 0.0069986	total: 2m 52s	remaining: 4m 12s
# 406:	learn: 0.0069942	total: 2m 53s	remaining: 4m 12s
# 407:	learn: 0.0069897	total: 2m 53s	remaining: 4m 12s
# 408:	learn: 0.0069854	total: 2m 54s	remaining: 4m 12s
# 409:	learn: 0.0069810	total: 2m 54s	remaining: 4m 11s
# 410:	learn: 0.0069769	total: 2m 55s	remaining: 4m 11s
# 411:	learn: 0.0069728	total: 2m 55s	remaining: 4m 11s
# 412:	learn: 0.0069550	total: 2m 56s	remaining: 4m 10s
# 413:	learn: 0.0069510	total: 2m 56s	remaining: 4m 10s
# 414:	learn: 0.0069244	total: 2m 57s	remaining: 4m 10s
# 415:	learn: 0.0069174	total: 2m 58s	remaining: 4m 10s
# 416:	learn: 0.0069138	total: 2m 58s	remaining: 4m 9s
# 417:	learn: 0.0069068	total: 2m 59s	remaining: 4m 9s
# 418:	learn: 0.0069006	total: 3m	remaining: 4m 9s
# 419:	learn: 0.0068775	total: 3m	remaining: 4m 9s
# 420:	learn: 0.0068736	total: 3m 1s	remaining: 4m 9s
# 421:	learn: 0.0068586	total: 3m 1s	remaining: 4m 9s
# 422:	learn: 0.0068338	total: 3m 2s	remaining: 4m 9s
# 423:	learn: 0.0068263	total: 3m 3s	remaining: 4m 8s
# 424:	learn: 0.0068220	total: 3m 3s	remaining: 4m 8s
# 425:	learn: 0.0068158	total: 3m 4s	remaining: 4m 8s
# 426:	learn: 0.0068117	total: 3m 4s	remaining: 4m 7s
# 427:	learn: 0.0068079	total: 3m 5s	remaining: 4m 7s
# 428:	learn: 0.0068002	total: 3m 5s	remaining: 4m 7s
# 429:	learn: 0.0067937	total: 3m 6s	remaining: 4m 6s
# 430:	learn: 0.0067891	total: 3m 6s	remaining: 4m 6s
# 431:	learn: 0.0067827	total: 3m 7s	remaining: 4m 6s
# 432:	learn: 0.0067780	total: 3m 8s	remaining: 4m 6s
# 433:	learn: 0.0067392	total: 3m 8s	remaining: 4m 6s
# 434:	learn: 0.0067349	total: 3m 9s	remaining: 4m 6s
# 435:	learn: 0.0067310	total: 3m 10s	remaining: 4m 5s
# 436:	learn: 0.0067271	total: 3m 10s	remaining: 4m 5s
# 437:	learn: 0.0067211	total: 3m 11s	remaining: 4m 5s
# 438:	learn: 0.0067065	total: 3m 12s	remaining: 4m 5s
# 439:	learn: 0.0067026	total: 3m 12s	remaining: 4m 5s
# 440:	learn: 0.0066988	total: 3m 13s	remaining: 4m 5s
# 441:	learn: 0.0066927	total: 3m 14s	remaining: 4m 4s
# 442:	learn: 0.0066885	total: 3m 14s	remaining: 4m 4s
# 443:	learn: 0.0066848	total: 3m 15s	remaining: 4m 4s
# 444:	learn: 0.0066811	total: 3m 15s	remaining: 4m 4s
# 445:	learn: 0.0066510	total: 3m 16s	remaining: 4m 3s
# 446:	learn: 0.0066437	total: 3m 16s	remaining: 4m 3s
# 447:	learn: 0.0066398	total: 3m 17s	remaining: 4m 3s
# 448:	learn: 0.0066359	total: 3m 18s	remaining: 4m 3s
# 449:	learn: 0.0066317	total: 3m 18s	remaining: 4m 2s
# 450:	learn: 0.0066033	total: 3m 19s	remaining: 4m 2s
# 451:	learn: 0.0065993	total: 3m 20s	remaining: 4m 2s
# 452:	learn: 0.0065947	total: 3m 20s	remaining: 4m 2s
# 453:	learn: 0.0065911	total: 3m 21s	remaining: 4m 2s
# 454:	learn: 0.0065875	total: 3m 22s	remaining: 4m 2s
# 455:	learn: 0.0065841	total: 3m 22s	remaining: 4m 1s
# 456:	learn: 0.0065806	total: 3m 23s	remaining: 4m 1s
# 457:	learn: 0.0065745	total: 3m 23s	remaining: 4m 1s
# 458:	learn: 0.0065710	total: 3m 24s	remaining: 4m
# 459:	learn: 0.0065398	total: 3m 25s	remaining: 4m
# 460:	learn: 0.0065370	total: 3m 25s	remaining: 4m
# 461:	learn: 0.0065343	total: 3m 26s	remaining: 4m
# 462:	learn: 0.0065312	total: 3m 26s	remaining: 4m
# 463:	learn: 0.0065280	total: 3m 27s	remaining: 3m 59s
# 464:	learn: 0.0065221	total: 3m 28s	remaining: 3m 59s
# 465:	learn: 0.0065172	total: 3m 28s	remaining: 3m 59s
# 466:	learn: 0.0065139	total: 3m 29s	remaining: 3m 59s
# 467:	learn: 0.0065060	total: 3m 30s	remaining: 3m 58s
# 468:	learn: 0.0064836	total: 3m 30s	remaining: 3m 58s
# 469:	learn: 0.0064567	total: 3m 31s	remaining: 3m 58s
# 470:	learn: 0.0064536	total: 3m 31s	remaining: 3m 57s
# 471:	learn: 0.0064506	total: 3m 32s	remaining: 3m 57s
# 472:	learn: 0.0064448	total: 3m 32s	remaining: 3m 57s
# 473:	learn: 0.0064111	total: 3m 33s	remaining: 3m 56s
# 474:	learn: 0.0064075	total: 3m 34s	remaining: 3m 56s
# 475:	learn: 0.0064043	total: 3m 34s	remaining: 3m 56s
# 476:	learn: 0.0064003	total: 3m 35s	remaining: 3m 55s
# 477:	learn: 0.0063973	total: 3m 35s	remaining: 3m 55s
# 478:	learn: 0.0063943	total: 3m 36s	remaining: 3m 55s
# 479:	learn: 0.0063913	total: 3m 36s	remaining: 3m 54s
# 480:	learn: 0.0063884	total: 3m 37s	remaining: 3m 54s
# 481:	learn: 0.0063665	total: 3m 37s	remaining: 3m 54s
# 482:	learn: 0.0063639	total: 3m 38s	remaining: 3m 53s
# 483:	learn: 0.0063588	total: 3m 38s	remaining: 3m 53s
# 484:	learn: 0.0063531	total: 3m 39s	remaining: 3m 52s
# 485:	learn: 0.0063499	total: 3m 39s	remaining: 3m 52s
# 486:	learn: 0.0063469	total: 3m 39s	remaining: 3m 51s
# 487:	learn: 0.0063357	total: 3m 40s	remaining: 3m 51s
# 488:	learn: 0.0063326	total: 3m 40s	remaining: 3m 50s
# 489:	learn: 0.0063155	total: 3m 41s	remaining: 3m 50s
# 490:	learn: 0.0063088	total: 3m 41s	remaining: 3m 50s
# 491:	learn: 0.0063051	total: 3m 42s	remaining: 3m 49s
# 492:	learn: 0.0062984	total: 3m 42s	remaining: 3m 49s
# 493:	learn: 0.0062958	total: 3m 43s	remaining: 3m 48s
# 494:	learn: 0.0062928	total: 3m 43s	remaining: 3m 48s
# 495:	learn: 0.0062897	total: 3m 44s	remaining: 3m 47s
# 496:	learn: 0.0062868	total: 3m 44s	remaining: 3m 47s
# 497:	learn: 0.0062840	total: 3m 45s	remaining: 3m 47s
# 498:	learn: 0.0062727	total: 3m 45s	remaining: 3m 46s
# 499:	learn: 0.0062387	total: 3m 46s	remaining: 3m 46s
# 500:	learn: 0.0062338	total: 3m 47s	remaining: 3m 46s
# 501:	learn: 0.0062275	total: 3m 47s	remaining: 3m 46s
# 502:	learn: 0.0062249	total: 3m 48s	remaining: 3m 45s
# 503:	learn: 0.0061973	total: 3m 48s	remaining: 3m 45s
# 504:	learn: 0.0061908	total: 3m 49s	remaining: 3m 44s
# 505:	learn: 0.0061885	total: 3m 49s	remaining: 3m 44s
# 506:	learn: 0.0061860	total: 3m 50s	remaining: 3m 44s
# 507:	learn: 0.0061834	total: 3m 50s	remaining: 3m 43s
# 508:	learn: 0.0061789	total: 3m 51s	remaining: 3m 43s
# 509:	learn: 0.0061750	total: 3m 51s	remaining: 3m 42s
# 510:	learn: 0.0061693	total: 3m 52s	remaining: 3m 42s
# 511:	learn: 0.0061656	total: 3m 52s	remaining: 3m 41s
# 512:	learn: 0.0061499	total: 3m 53s	remaining: 3m 41s
# 513:	learn: 0.0061462	total: 3m 54s	remaining: 3m 41s
# 514:	learn: 0.0061405	total: 3m 54s	remaining: 3m 40s
# 515:	learn: 0.0061130	total: 3m 55s	remaining: 3m 40s
# 516:	learn: 0.0061005	total: 3m 55s	remaining: 3m 40s
# 517:	learn: 0.0060975	total: 3m 56s	remaining: 3m 39s
# 518:	learn: 0.0060955	total: 3m 56s	remaining: 3m 39s
# 519:	learn: 0.0060932	total: 3m 57s	remaining: 3m 38s
# 520:	learn: 0.0060895	total: 3m 57s	remaining: 3m 38s
# 521:	learn: 0.0060865	total: 3m 58s	remaining: 3m 38s
# 522:	learn: 0.0060837	total: 3m 59s	remaining: 3m 38s
# 523:	learn: 0.0060813	total: 3m 59s	remaining: 3m 37s
# 524:	learn: 0.0060788	total: 4m	remaining: 3m 37s
# 525:	learn: 0.0060763	total: 4m	remaining: 3m 37s
# 526:	learn: 0.0060707	total: 4m 1s	remaining: 3m 36s
# 527:	learn: 0.0060683	total: 4m 1s	remaining: 3m 36s
# 528:	learn: 0.0060622	total: 4m 2s	remaining: 3m 35s
# 529:	learn: 0.0060576	total: 4m 2s	remaining: 3m 35s
# 530:	learn: 0.0060550	total: 4m 3s	remaining: 3m 35s
# 531:	learn: 0.0060417	total: 4m 4s	remaining: 3m 34s
# 532:	learn: 0.0060389	total: 4m 4s	remaining: 3m 34s
# 533:	learn: 0.0060259	total: 4m 5s	remaining: 3m 33s
# 534:	learn: 0.0060101	total: 4m 5s	remaining: 3m 33s
# 535:	learn: 0.0059931	total: 4m 5s	remaining: 3m 32s
# 536:	learn: 0.0059845	total: 4m 6s	remaining: 3m 32s
# 537:	learn: 0.0059813	total: 4m 6s	remaining: 3m 31s
# 538:	learn: 0.0059790	total: 4m 7s	remaining: 3m 31s
# 539:	learn: 0.0059740	total: 4m 8s	remaining: 3m 31s
# 540:	learn: 0.0059617	total: 4m 8s	remaining: 3m 30s
# 541:	learn: 0.0059569	total: 4m 9s	remaining: 3m 30s
# 542:	learn: 0.0059382	total: 4m 9s	remaining: 3m 30s
# 543:	learn: 0.0059297	total: 4m 10s	remaining: 3m 29s
# 544:	learn: 0.0059269	total: 4m 10s	remaining: 3m 29s
# 545:	learn: 0.0059246	total: 4m 11s	remaining: 3m 29s
# 546:	learn: 0.0059225	total: 4m 12s	remaining: 3m 28s
# 547:	learn: 0.0059176	total: 4m 12s	remaining: 3m 28s
# 548:	learn: 0.0059155	total: 4m 13s	remaining: 3m 28s
# 549:	learn: 0.0059118	total: 4m 14s	remaining: 3m 27s
# 550:	learn: 0.0059097	total: 4m 14s	remaining: 3m 27s
# 551:	learn: 0.0058819	total: 4m 15s	remaining: 3m 27s
# 552:	learn: 0.0058792	total: 4m 15s	remaining: 3m 26s
# 553:	learn: 0.0058766	total: 4m 16s	remaining: 3m 26s
# 554:	learn: 0.0058741	total: 4m 16s	remaining: 3m 26s
# 555:	learn: 0.0058717	total: 4m 17s	remaining: 3m 25s
# 556:	learn: 0.0058277	total: 4m 18s	remaining: 3m 25s
# 557:	learn: 0.0058255	total: 4m 18s	remaining: 3m 24s
# 558:	learn: 0.0058207	total: 4m 19s	remaining: 3m 24s
# 559:	learn: 0.0058183	total: 4m 19s	remaining: 3m 24s
# 560:	learn: 0.0058139	total: 4m 20s	remaining: 3m 23s
# 561:	learn: 0.0058116	total: 4m 20s	remaining: 3m 23s
# 562:	learn: 0.0058063	total: 4m 21s	remaining: 3m 23s
# 563:	learn: 0.0057932	total: 4m 22s	remaining: 3m 22s
# 564:	learn: 0.0057902	total: 4m 22s	remaining: 3m 22s
# 565:	learn: 0.0057817	total: 4m 23s	remaining: 3m 21s
# 566:	learn: 0.0057315	total: 4m 23s	remaining: 3m 21s
# 567:	learn: 0.0057292	total: 4m 24s	remaining: 3m 21s
# 568:	learn: 0.0057181	total: 4m 25s	remaining: 3m 20s
# 569:	learn: 0.0057138	total: 4m 25s	remaining: 3m 20s
# 570:	learn: 0.0057101	total: 4m 26s	remaining: 3m 20s
# 571:	learn: 0.0057022	total: 4m 26s	remaining: 3m 19s
# 572:	learn: 0.0057001	total: 4m 27s	remaining: 3m 19s
# 573:	learn: 0.0056949	total: 4m 28s	remaining: 3m 19s
# 574:	learn: 0.0056912	total: 4m 28s	remaining: 3m 18s
# 575:	learn: 0.0056859	total: 4m 29s	remaining: 3m 18s
# 576:	learn: 0.0056787	total: 4m 30s	remaining: 3m 17s
# 577:	learn: 0.0056767	total: 4m 30s	remaining: 3m 17s
# 578:	learn: 0.0056730	total: 4m 31s	remaining: 3m 17s
# 579:	learn: 0.0056684	total: 4m 31s	remaining: 3m 16s
# 580:	learn: 0.0056587	total: 4m 32s	remaining: 3m 16s
# 581:	learn: 0.0056559	total: 4m 33s	remaining: 3m 16s
# 582:	learn: 0.0056540	total: 4m 33s	remaining: 3m 15s
# 583:	learn: 0.0056510	total: 4m 34s	remaining: 3m 15s
# 584:	learn: 0.0056447	total: 4m 35s	remaining: 3m 15s
# 585:	learn: 0.0056428	total: 4m 35s	remaining: 3m 14s
# 586:	learn: 0.0056408	total: 4m 36s	remaining: 3m 14s
# 587:	learn: 0.0056352	total: 4m 37s	remaining: 3m 14s
# 588:	learn: 0.0056331	total: 4m 37s	remaining: 3m 13s
# 589:	learn: 0.0056284	total: 4m 38s	remaining: 3m 13s
# 590:	learn: 0.0056264	total: 4m 38s	remaining: 3m 12s
# 591:	learn: 0.0056246	total: 4m 39s	remaining: 3m 12s
# 592:	learn: 0.0056223	total: 4m 39s	remaining: 3m 12s
# 593:	learn: 0.0056135	total: 4m 40s	remaining: 3m 11s
# 594:	learn: 0.0056111	total: 4m 41s	remaining: 3m 11s
# 595:	learn: 0.0055927	total: 4m 41s	remaining: 3m 11s
# 596:	learn: 0.0055901	total: 4m 42s	remaining: 3m 10s
# 597:	learn: 0.0055632	total: 4m 43s	remaining: 3m 10s
# 598:	learn: 0.0055606	total: 4m 44s	remaining: 3m 10s
# 599:	learn: 0.0055583	total: 4m 45s	remaining: 3m 10s
# 600:	learn: 0.0055525	total: 4m 45s	remaining: 3m 9s
# 601:	learn: 0.0055505	total: 4m 46s	remaining: 3m 9s
# 602:	learn: 0.0055250	total: 4m 46s	remaining: 3m 8s
# 603:	learn: 0.0055232	total: 4m 47s	remaining: 3m 8s
# 604:	learn: 0.0055201	total: 4m 47s	remaining: 3m 7s
# 605:	learn: 0.0055172	total: 4m 48s	remaining: 3m 7s
# 606:	learn: 0.0055124	total: 4m 48s	remaining: 3m 7s
# 607:	learn: 0.0055106	total: 4m 49s	remaining: 3m 6s
# 608:	learn: 0.0055063	total: 4m 50s	remaining: 3m 6s
# 609:	learn: 0.0055022	total: 4m 50s	remaining: 3m 5s
# 610:	learn: 0.0054943	total: 4m 51s	remaining: 3m 5s
# 611:	learn: 0.0054921	total: 4m 51s	remaining: 3m 4s
# 612:	learn: 0.0054684	total: 4m 52s	remaining: 3m 4s
# 613:	learn: 0.0054618	total: 4m 52s	remaining: 3m 3s
# 614:	learn: 0.0054577	total: 4m 53s	remaining: 3m 3s
# 615:	learn: 0.0054555	total: 4m 53s	remaining: 3m 3s
# 616:	learn: 0.0054520	total: 4m 54s	remaining: 3m 2s
# 617:	learn: 0.0054503	total: 4m 54s	remaining: 3m 2s
# 618:	learn: 0.0054420	total: 4m 55s	remaining: 3m 1s
# 619:	learn: 0.0054382	total: 4m 55s	remaining: 3m 1s
# 620:	learn: 0.0054363	total: 4m 56s	remaining: 3m
# 621:	learn: 0.0054343	total: 4m 56s	remaining: 3m
# 622:	learn: 0.0054326	total: 4m 57s	remaining: 2m 59s
# 623:	learn: 0.0054308	total: 4m 57s	remaining: 2m 59s
# 624:	learn: 0.0054173	total: 4m 58s	remaining: 2m 58s
# 625:	learn: 0.0054126	total: 4m 58s	remaining: 2m 58s
# 626:	learn: 0.0054108	total: 4m 59s	remaining: 2m 58s
# 627:	learn: 0.0054092	total: 4m 59s	remaining: 2m 57s
# 628:	learn: 0.0054075	total: 5m	remaining: 2m 57s
# 629:	learn: 0.0053930	total: 5m	remaining: 2m 56s
# 630:	learn: 0.0053914	total: 5m 1s	remaining: 2m 56s
# 631:	learn: 0.0053894	total: 5m 2s	remaining: 2m 56s
# 632:	learn: 0.0053872	total: 5m 3s	remaining: 2m 55s
# 633:	learn: 0.0053851	total: 5m 3s	remaining: 2m 55s
# 634:	learn: 0.0053789	total: 5m 4s	remaining: 2m 55s
# 635:	learn: 0.0053772	total: 5m 5s	remaining: 2m 54s
# 636:	learn: 0.0053685	total: 5m 5s	remaining: 2m 54s
# 637:	learn: 0.0053669	total: 5m 6s	remaining: 2m 53s
# 638:	learn: 0.0053630	total: 5m 6s	remaining: 2m 53s
# 639:	learn: 0.0053608	total: 5m 7s	remaining: 2m 52s
# 640:	learn: 0.0053577	total: 5m 8s	remaining: 2m 52s
# 641:	learn: 0.0053545	total: 5m 8s	remaining: 2m 52s
# 642:	learn: 0.0053467	total: 5m 9s	remaining: 2m 51s
# 643:	learn: 0.0053433	total: 5m 9s	remaining: 2m 51s
# 644:	learn: 0.0053414	total: 5m 10s	remaining: 2m 50s
# 645:	learn: 0.0053256	total: 5m 10s	remaining: 2m 50s
# 646:	learn: 0.0053240	total: 5m 11s	remaining: 2m 49s
# 647:	learn: 0.0053210	total: 5m 12s	remaining: 2m 49s
# 648:	learn: 0.0053197	total: 5m 12s	remaining: 2m 49s
# 649:	learn: 0.0053071	total: 5m 13s	remaining: 2m 48s
# 650:	learn: 0.0053038	total: 5m 14s	remaining: 2m 48s
# 651:	learn: 0.0052951	total: 5m 14s	remaining: 2m 48s
# 652:	learn: 0.0052915	total: 5m 15s	remaining: 2m 47s
# 653:	learn: 0.0052897	total: 5m 16s	remaining: 2m 47s
# 654:	learn: 0.0052884	total: 5m 17s	remaining: 2m 47s
# 655:	learn: 0.0052868	total: 5m 17s	remaining: 2m 46s
# 656:	learn: 0.0052815	total: 5m 18s	remaining: 2m 46s
# 657:	learn: 0.0052791	total: 5m 19s	remaining: 2m 45s
# 658:	learn: 0.0052762	total: 5m 19s	remaining: 2m 45s
# 659:	learn: 0.0052742	total: 5m 20s	remaining: 2m 45s
# 660:	learn: 0.0052729	total: 5m 21s	remaining: 2m 44s
# 661:	learn: 0.0052701	total: 5m 21s	remaining: 2m 44s
# 662:	learn: 0.0052686	total: 5m 22s	remaining: 2m 43s
# 663:	learn: 0.0052669	total: 5m 22s	remaining: 2m 43s
# 664:	learn: 0.0052649	total: 5m 23s	remaining: 2m 42s
# 665:	learn: 0.0052620	total: 5m 23s	remaining: 2m 42s
# 666:	learn: 0.0052538	total: 5m 24s	remaining: 2m 42s
# 667:	learn: 0.0052518	total: 5m 25s	remaining: 2m 41s
# 668:	learn: 0.0052491	total: 5m 25s	remaining: 2m 41s
# 669:	learn: 0.0052446	total: 5m 26s	remaining: 2m 40s
# 670:	learn: 0.0052384	total: 5m 26s	remaining: 2m 40s
# 671:	learn: 0.0052364	total: 5m 27s	remaining: 2m 39s
# 672:	learn: 0.0052343	total: 5m 27s	remaining: 2m 39s
# 673:	learn: 0.0052323	total: 5m 28s	remaining: 2m 38s
# 674:	learn: 0.0052257	total: 5m 28s	remaining: 2m 38s
# 675:	learn: 0.0052235	total: 5m 29s	remaining: 2m 37s
# 676:	learn: 0.0051988	total: 5m 30s	remaining: 2m 37s
# 677:	learn: 0.0051946	total: 5m 30s	remaining: 2m 36s
# 678:	learn: 0.0051932	total: 5m 31s	remaining: 2m 36s
# 679:	learn: 0.0051754	total: 5m 31s	remaining: 2m 36s
# 680:	learn: 0.0051721	total: 5m 32s	remaining: 2m 35s
# 681:	learn: 0.0051688	total: 5m 32s	remaining: 2m 35s
# 682:	learn: 0.0051665	total: 5m 33s	remaining: 2m 34s
# 683:	learn: 0.0051649	total: 5m 33s	remaining: 2m 34s
# 684:	learn: 0.0051637	total: 5m 34s	remaining: 2m 33s
# 685:	learn: 0.0051619	total: 5m 34s	remaining: 2m 33s
# 686:	learn: 0.0051505	total: 5m 35s	remaining: 2m 32s
# 687:	learn: 0.0051481	total: 5m 35s	remaining: 2m 32s
# 688:	learn: 0.0051377	total: 5m 36s	remaining: 2m 31s
# 689:	learn: 0.0051358	total: 5m 36s	remaining: 2m 31s
# 690:	learn: 0.0051308	total: 5m 37s	remaining: 2m 30s
# 691:	learn: 0.0051281	total: 5m 37s	remaining: 2m 30s
# 692:	learn: 0.0051263	total: 5m 38s	remaining: 2m 29s
# 693:	learn: 0.0051233	total: 5m 38s	remaining: 2m 29s
# 694:	learn: 0.0051159	total: 5m 39s	remaining: 2m 28s
# 695:	learn: 0.0051142	total: 5m 39s	remaining: 2m 28s
# 696:	learn: 0.0051107	total: 5m 40s	remaining: 2m 27s
# 697:	learn: 0.0050967	total: 5m 40s	remaining: 2m 27s
# 698:	learn: 0.0050850	total: 5m 41s	remaining: 2m 26s
# 699:	learn: 0.0050780	total: 5m 41s	remaining: 2m 26s
# 700:	learn: 0.0050558	total: 5m 42s	remaining: 2m 26s
# 701:	learn: 0.0050526	total: 5m 42s	remaining: 2m 25s
# 702:	learn: 0.0050511	total: 5m 43s	remaining: 2m 25s
# 703:	learn: 0.0050479	total: 5m 43s	remaining: 2m 24s
# 704:	learn: 0.0050467	total: 5m 44s	remaining: 2m 24s
# 705:	learn: 0.0050447	total: 5m 44s	remaining: 2m 23s
# 706:	learn: 0.0050419	total: 5m 45s	remaining: 2m 23s
# 707:	learn: 0.0050397	total: 5m 45s	remaining: 2m 22s
# 708:	learn: 0.0050324	total: 5m 46s	remaining: 2m 22s
# 709:	learn: 0.0050311	total: 5m 46s	remaining: 2m 21s
# 710:	learn: 0.0050286	total: 5m 47s	remaining: 2m 21s
# 711:	learn: 0.0050254	total: 5m 48s	remaining: 2m 20s
# 712:	learn: 0.0050235	total: 5m 48s	remaining: 2m 20s
# 713:	learn: 0.0050206	total: 5m 49s	remaining: 2m 19s
# 714:	learn: 0.0050188	total: 5m 49s	remaining: 2m 19s
# 715:	learn: 0.0050065	total: 5m 50s	remaining: 2m 18s
# 716:	learn: 0.0050046	total: 5m 51s	remaining: 2m 18s
# 717:	learn: 0.0050034	total: 5m 51s	remaining: 2m 18s
# 718:	learn: 0.0049976	total: 5m 52s	remaining: 2m 17s
# 719:	learn: 0.0049960	total: 5m 53s	remaining: 2m 17s
# 720:	learn: 0.0049898	total: 5m 53s	remaining: 2m 16s
# 721:	learn: 0.0049868	total: 5m 54s	remaining: 2m 16s
# 722:	learn: 0.0049788	total: 5m 54s	remaining: 2m 15s
# 723:	learn: 0.0049722	total: 5m 55s	remaining: 2m 15s
# 724:	learn: 0.0049635	total: 5m 55s	remaining: 2m 15s
# 725:	learn: 0.0049619	total: 5m 56s	remaining: 2m 14s
# 726:	learn: 0.0049592	total: 5m 56s	remaining: 2m 14s
# 727:	learn: 0.0049576	total: 5m 57s	remaining: 2m 13s
# 728:	learn: 0.0049480	total: 5m 57s	remaining: 2m 13s
# 729:	learn: 0.0049466	total: 5m 58s	remaining: 2m 12s
# 730:	learn: 0.0049450	total: 5m 58s	remaining: 2m 12s
# 731:	learn: 0.0049370	total: 5m 59s	remaining: 2m 11s
# 732:	learn: 0.0049306	total: 5m 59s	remaining: 2m 11s
# 733:	learn: 0.0049270	total: 6m	remaining: 2m 10s
# 734:	learn: 0.0049251	total: 6m	remaining: 2m 10s
# 735:	learn: 0.0049198	total: 6m 1s	remaining: 2m 9s
# 736:	learn: 0.0049044	total: 6m 1s	remaining: 2m 9s
# 737:	learn: 0.0049021	total: 6m 2s	remaining: 2m 8s
# 738:	learn: 0.0048904	total: 6m 2s	remaining: 2m 8s
# 739:	learn: 0.0048892	total: 6m 3s	remaining: 2m 7s
# 740:	learn: 0.0048734	total: 6m 3s	remaining: 2m 7s
# 741:	learn: 0.0048711	total: 6m 4s	remaining: 2m 6s
# 742:	learn: 0.0048702	total: 6m 4s	remaining: 2m 6s
# 743:	learn: 0.0048664	total: 6m 5s	remaining: 2m 5s
# 744:	learn: 0.0048644	total: 6m 5s	remaining: 2m 5s
# 745:	learn: 0.0048635	total: 6m 6s	remaining: 2m 4s
# 746:	learn: 0.0048540	total: 6m 6s	remaining: 2m 4s
# 747:	learn: 0.0048524	total: 6m 7s	remaining: 2m 3s
# 748:	learn: 0.0048498	total: 6m 7s	remaining: 2m 3s
# 749:	learn: 0.0048474	total: 6m 8s	remaining: 2m 2s
# 750:	learn: 0.0048462	total: 6m 8s	remaining: 2m 2s
# 751:	learn: 0.0048451	total: 6m 9s	remaining: 2m 1s
# 752:	learn: 0.0048427	total: 6m 9s	remaining: 2m 1s
# 753:	learn: 0.0048408	total: 6m 10s	remaining: 2m
# 754:	learn: 0.0048389	total: 6m 10s	remaining: 2m
# 755:	learn: 0.0048369	total: 6m 11s	remaining: 1m 59s
# 756:	learn: 0.0048358	total: 6m 11s	remaining: 1m 59s
# 757:	learn: 0.0048319	total: 6m 12s	remaining: 1m 58s
# 758:	learn: 0.0048285	total: 6m 12s	remaining: 1m 58s
# 759:	learn: 0.0048221	total: 6m 13s	remaining: 1m 57s
# 760:	learn: 0.0048203	total: 6m 13s	remaining: 1m 57s
# 761:	learn: 0.0048178	total: 6m 14s	remaining: 1m 56s
# 762:	learn: 0.0048155	total: 6m 14s	remaining: 1m 56s
# 763:	learn: 0.0048117	total: 6m 15s	remaining: 1m 55s
# 764:	learn: 0.0048097	total: 6m 15s	remaining: 1m 55s
# 765:	learn: 0.0048087	total: 6m 16s	remaining: 1m 54s
# 766:	learn: 0.0048073	total: 6m 16s	remaining: 1m 54s
# 767:	learn: 0.0048056	total: 6m 17s	remaining: 1m 53s
# 768:	learn: 0.0047994	total: 6m 17s	remaining: 1m 53s
# 769:	learn: 0.0047982	total: 6m 18s	remaining: 1m 53s
# 770:	learn: 0.0047854	total: 6m 19s	remaining: 1m 52s
# 771:	learn: 0.0047805	total: 6m 19s	remaining: 1m 52s
# 772:	learn: 0.0047736	total: 6m 20s	remaining: 1m 51s
# 773:	learn: 0.0047703	total: 6m 20s	remaining: 1m 51s
# 774:	learn: 0.0047558	total: 6m 21s	remaining: 1m 50s
# 775:	learn: 0.0047539	total: 6m 21s	remaining: 1m 50s
# 776:	learn: 0.0047520	total: 6m 22s	remaining: 1m 49s
# 777:	learn: 0.0047487	total: 6m 22s	remaining: 1m 49s
# 778:	learn: 0.0047465	total: 6m 23s	remaining: 1m 48s
# 779:	learn: 0.0047446	total: 6m 23s	remaining: 1m 48s
# 780:	learn: 0.0047135	total: 6m 24s	remaining: 1m 47s
# 781:	learn: 0.0047120	total: 6m 24s	remaining: 1m 47s
# 782:	learn: 0.0047098	total: 6m 25s	remaining: 1m 46s
# 783:	learn: 0.0046893	total: 6m 25s	remaining: 1m 46s
# 784:	learn: 0.0046864	total: 6m 26s	remaining: 1m 45s
# 785:	learn: 0.0046839	total: 6m 26s	remaining: 1m 45s
# 786:	learn: 0.0046831	total: 6m 27s	remaining: 1m 44s
# 787:	learn: 0.0046813	total: 6m 27s	remaining: 1m 44s
# 788:	learn: 0.0046660	total: 6m 28s	remaining: 1m 43s
# 789:	learn: 0.0046552	total: 6m 28s	remaining: 1m 43s
# 790:	learn: 0.0046537	total: 6m 29s	remaining: 1m 42s
# 791:	learn: 0.0046529	total: 6m 29s	remaining: 1m 42s
# 792:	learn: 0.0046520	total: 6m 29s	remaining: 1m 41s
# 793:	learn: 0.0046508	total: 6m 30s	remaining: 1m 41s
# 794:	learn: 0.0046493	total: 6m 30s	remaining: 1m 40s
# 795:	learn: 0.0046370	total: 6m 31s	remaining: 1m 40s
# 796:	learn: 0.0046348	total: 6m 31s	remaining: 1m 39s
# 797:	learn: 0.0046336	total: 6m 32s	remaining: 1m 39s
# 798:	learn: 0.0046285	total: 6m 32s	remaining: 1m 38s
# 799:	learn: 0.0046275	total: 6m 33s	remaining: 1m 38s
# 800:	learn: 0.0046264	total: 6m 33s	remaining: 1m 37s
# 801:	learn: 0.0046172	total: 6m 34s	remaining: 1m 37s
# 802:	learn: 0.0046159	total: 6m 34s	remaining: 1m 36s
# 803:	learn: 0.0046150	total: 6m 35s	remaining: 1m 36s
# 804:	learn: 0.0046133	total: 6m 35s	remaining: 1m 35s
# 805:	learn: 0.0046099	total: 6m 36s	remaining: 1m 35s
# 806:	learn: 0.0046081	total: 6m 36s	remaining: 1m 34s
# 807:	learn: 0.0046012	total: 6m 37s	remaining: 1m 34s
# 808:	learn: 0.0046001	total: 6m 38s	remaining: 1m 33s
# 809:	learn: 0.0045985	total: 6m 38s	remaining: 1m 33s
# 810:	learn: 0.0045913	total: 6m 39s	remaining: 1m 33s
# 811:	learn: 0.0045901	total: 6m 39s	remaining: 1m 32s
# 812:	learn: 0.0045875	total: 6m 40s	remaining: 1m 32s
# 813:	learn: 0.0045843	total: 6m 40s	remaining: 1m 31s
# 814:	learn: 0.0045782	total: 6m 41s	remaining: 1m 31s
# 815:	learn: 0.0045764	total: 6m 41s	remaining: 1m 30s
# 816:	learn: 0.0045743	total: 6m 42s	remaining: 1m 30s
# 817:	learn: 0.0045654	total: 6m 42s	remaining: 1m 29s
# 818:	learn: 0.0045645	total: 6m 43s	remaining: 1m 29s
# 819:	learn: 0.0045630	total: 6m 43s	remaining: 1m 28s
# 820:	learn: 0.0045527	total: 6m 44s	remaining: 1m 28s
# 821:	learn: 0.0045416	total: 6m 44s	remaining: 1m 27s
# 822:	learn: 0.0045407	total: 6m 45s	remaining: 1m 27s
# 823:	learn: 0.0045392	total: 6m 45s	remaining: 1m 26s
# 824:	learn: 0.0045367	total: 6m 46s	remaining: 1m 26s
# 825:	learn: 0.0045352	total: 6m 46s	remaining: 1m 25s
# 826:	learn: 0.0045295	total: 6m 47s	remaining: 1m 25s
# 827:	learn: 0.0045281	total: 6m 47s	remaining: 1m 24s
# 828:	learn: 0.0045262	total: 6m 48s	remaining: 1m 24s
# 829:	learn: 0.0045166	total: 6m 48s	remaining: 1m 23s
# 830:	learn: 0.0045153	total: 6m 49s	remaining: 1m 23s
# 831:	learn: 0.0045142	total: 6m 49s	remaining: 1m 22s
# 832:	learn: 0.0045122	total: 6m 50s	remaining: 1m 22s
# 833:	learn: 0.0045073	total: 6m 50s	remaining: 1m 21s
# 834:	learn: 0.0045057	total: 6m 51s	remaining: 1m 21s
# 835:	learn: 0.0045047	total: 6m 51s	remaining: 1m 20s
# 836:	learn: 0.0045035	total: 6m 52s	remaining: 1m 20s
# 837:	learn: 0.0045025	total: 6m 52s	remaining: 1m 19s
# 838:	learn: 0.0045007	total: 6m 53s	remaining: 1m 19s
# 839:	learn: 0.0044991	total: 6m 53s	remaining: 1m 18s
# 840:	learn: 0.0044982	total: 6m 54s	remaining: 1m 18s
# 841:	learn: 0.0044966	total: 6m 54s	remaining: 1m 17s
# 842:	learn: 0.0044924	total: 6m 55s	remaining: 1m 17s
# 843:	learn: 0.0044903	total: 6m 55s	remaining: 1m 16s
# 844:	learn: 0.0044848	total: 6m 56s	remaining: 1m 16s
# 845:	learn: 0.0044833	total: 6m 56s	remaining: 1m 15s
# 846:	learn: 0.0044754	total: 6m 57s	remaining: 1m 15s
# 847:	learn: 0.0044737	total: 6m 57s	remaining: 1m 14s
# 848:	learn: 0.0044718	total: 6m 58s	remaining: 1m 14s
# 849:	learn: 0.0044697	total: 6m 58s	remaining: 1m 13s
# 850:	learn: 0.0044681	total: 6m 59s	remaining: 1m 13s
# 851:	learn: 0.0044673	total: 6m 59s	remaining: 1m 12s
# 852:	learn: 0.0044557	total: 7m	remaining: 1m 12s
# 853:	learn: 0.0044541	total: 7m	remaining: 1m 11s
# 854:	learn: 0.0044494	total: 7m 1s	remaining: 1m 11s
# 855:	learn: 0.0044435	total: 7m 1s	remaining: 1m 10s
# 856:	learn: 0.0044420	total: 7m 2s	remaining: 1m 10s
# 857:	learn: 0.0044348	total: 7m 2s	remaining: 1m 9s
# 858:	learn: 0.0044320	total: 7m 3s	remaining: 1m 9s
# 859:	learn: 0.0044245	total: 7m 3s	remaining: 1m 8s
# 860:	learn: 0.0044229	total: 7m 4s	remaining: 1m 8s
# 861:	learn: 0.0044218	total: 7m 4s	remaining: 1m 7s
# 862:	learn: 0.0044176	total: 7m 5s	remaining: 1m 7s
# 863:	learn: 0.0044097	total: 7m 5s	remaining: 1m 6s
# 864:	learn: 0.0044040	total: 7m 6s	remaining: 1m 6s
# 865:	learn: 0.0044025	total: 7m 6s	remaining: 1m 5s
# 866:	learn: 0.0043969	total: 7m 7s	remaining: 1m 5s
# 867:	learn: 0.0043955	total: 7m 7s	remaining: 1m 5s
# 868:	learn: 0.0043873	total: 7m 8s	remaining: 1m 4s
# 869:	learn: 0.0043863	total: 7m 8s	remaining: 1m 4s
# 870:	learn: 0.0043837	total: 7m 9s	remaining: 1m 3s
# 871:	learn: 0.0043825	total: 7m 9s	remaining: 1m 3s
# 872:	learn: 0.0043738	total: 7m 10s	remaining: 1m 2s
# 873:	learn: 0.0043723	total: 7m 10s	remaining: 1m 2s
# 874:	learn: 0.0043656	total: 7m 11s	remaining: 1m 1s
# 875:	learn: 0.0043631	total: 7m 11s	remaining: 1m 1s
# 876:	learn: 0.0043616	total: 7m 11s	remaining: 1m
# 877:	learn: 0.0043600	total: 7m 12s	remaining: 1m
# 878:	learn: 0.0043592	total: 7m 12s	remaining: 59.6s
# 879:	learn: 0.0043576	total: 7m 13s	remaining: 59.1s
# 880:	learn: 0.0043568	total: 7m 13s	remaining: 58.6s
# 881:	learn: 0.0043539	total: 7m 14s	remaining: 58.1s
# 882:	learn: 0.0043482	total: 7m 14s	remaining: 57.6s
# 883:	learn: 0.0043466	total: 7m 15s	remaining: 57.1s
# 884:	learn: 0.0043376	total: 7m 15s	remaining: 56.6s
# 885:	learn: 0.0043359	total: 7m 16s	remaining: 56.2s
# 886:	learn: 0.0043272	total: 7m 17s	remaining: 55.7s
# 887:	learn: 0.0043265	total: 7m 17s	remaining: 55.2s
# 888:	learn: 0.0043243	total: 7m 18s	remaining: 54.7s
# 889:	learn: 0.0043162	total: 7m 18s	remaining: 54.2s
# 890:	learn: 0.0043106	total: 7m 19s	remaining: 53.7s
# 891:	learn: 0.0043098	total: 7m 19s	remaining: 53.2s
# 892:	learn: 0.0043037	total: 7m 20s	remaining: 52.7s
# 893:	learn: 0.0043027	total: 7m 20s	remaining: 52.3s
# 894:	learn: 0.0043017	total: 7m 21s	remaining: 51.8s
# 895:	learn: 0.0043005	total: 7m 21s	remaining: 51.3s
# 896:	learn: 0.0042979	total: 7m 22s	remaining: 50.8s
# 897:	learn: 0.0042905	total: 7m 22s	remaining: 50.3s
# 898:	learn: 0.0042830	total: 7m 23s	remaining: 49.8s
# 899:	learn: 0.0042821	total: 7m 23s	remaining: 49.3s
# 900:	learn: 0.0042768	total: 7m 24s	remaining: 48.8s
# 901:	learn: 0.0042754	total: 7m 24s	remaining: 48.3s
# 902:	learn: 0.0042739	total: 7m 25s	remaining: 47.8s
# 903:	learn: 0.0042722	total: 7m 25s	remaining: 47.3s
# 904:	learn: 0.0042610	total: 7m 26s	remaining: 46.8s
# 905:	learn: 0.0042541	total: 7m 26s	remaining: 46.3s
# 906:	learn: 0.0042490	total: 7m 27s	remaining: 45.9s
# 907:	learn: 0.0042480	total: 7m 27s	remaining: 45.4s
# 908:	learn: 0.0042466	total: 7m 28s	remaining: 44.9s
# 909:	learn: 0.0042370	total: 7m 28s	remaining: 44.4s
# 910:	learn: 0.0042340	total: 7m 29s	remaining: 43.9s
# 911:	learn: 0.0042319	total: 7m 29s	remaining: 43.4s
# 912:	learn: 0.0042259	total: 7m 30s	remaining: 42.9s
# 913:	learn: 0.0042249	total: 7m 30s	remaining: 42.4s
# 914:	learn: 0.0042231	total: 7m 31s	remaining: 41.9s
# 915:	learn: 0.0042216	total: 7m 31s	remaining: 41.4s
# 916:	learn: 0.0042202	total: 7m 32s	remaining: 40.9s
# 917:	learn: 0.0042113	total: 7m 32s	remaining: 40.4s
# 918:	learn: 0.0042105	total: 7m 33s	remaining: 39.9s
# 919:	learn: 0.0042097	total: 7m 33s	remaining: 39.4s
# 920:	learn: 0.0042067	total: 7m 34s	remaining: 39s
# 921:	learn: 0.0041878	total: 7m 34s	remaining: 38.5s
# 922:	learn: 0.0041862	total: 7m 35s	remaining: 38s
# 923:	learn: 0.0041848	total: 7m 35s	remaining: 37.5s
# 924:	learn: 0.0041784	total: 7m 36s	remaining: 37s
# 925:	learn: 0.0041776	total: 7m 36s	remaining: 36.5s
# 926:	learn: 0.0041755	total: 7m 37s	remaining: 36s
# 927:	learn: 0.0041742	total: 7m 37s	remaining: 35.5s
# 928:	learn: 0.0041700	total: 7m 38s	remaining: 35s
# 929:	learn: 0.0041688	total: 7m 38s	remaining: 34.5s
# 930:	learn: 0.0041682	total: 7m 39s	remaining: 34s
# 931:	learn: 0.0041639	total: 7m 39s	remaining: 33.5s
# 932:	learn: 0.0041591	total: 7m 40s	remaining: 33s
# 933:	learn: 0.0041580	total: 7m 40s	remaining: 32.5s
# 934:	learn: 0.0041568	total: 7m 40s	remaining: 32s
# 935:	learn: 0.0041562	total: 7m 41s	remaining: 31.6s
# 936:	learn: 0.0041536	total: 7m 41s	remaining: 31.1s
# 937:	learn: 0.0041473	total: 7m 42s	remaining: 30.6s
# 938:	learn: 0.0041415	total: 7m 42s	remaining: 30.1s
# 939:	learn: 0.0041404	total: 7m 43s	remaining: 29.6s
# 940:	learn: 0.0041356	total: 7m 43s	remaining: 29.1s
# 941:	learn: 0.0041343	total: 7m 44s	remaining: 28.6s
# 942:	learn: 0.0041320	total: 7m 44s	remaining: 28.1s
# 943:	learn: 0.0041310	total: 7m 45s	remaining: 27.6s
# 944:	learn: 0.0041301	total: 7m 45s	remaining: 27.1s
# 945:	learn: 0.0041288	total: 7m 46s	remaining: 26.6s
# 946:	learn: 0.0041241	total: 7m 46s	remaining: 26.1s
# 947:	learn: 0.0041228	total: 7m 47s	remaining: 25.6s
# 948:	learn: 0.0041212	total: 7m 47s	remaining: 25.1s
# 949:	learn: 0.0041197	total: 7m 48s	remaining: 24.7s
# 950:	learn: 0.0041181	total: 7m 48s	remaining: 24.2s
# 951:	learn: 0.0041148	total: 7m 49s	remaining: 23.7s
# 952:	learn: 0.0041140	total: 7m 49s	remaining: 23.2s
# 953:	learn: 0.0041092	total: 7m 50s	remaining: 22.7s
# 954:	learn: 0.0041082	total: 7m 50s	remaining: 22.2s
# 955:	learn: 0.0041037	total: 7m 51s	remaining: 21.7s
# 956:	learn: 0.0041012	total: 7m 51s	remaining: 21.2s
# 957:	learn: 0.0040969	total: 7m 52s	remaining: 20.7s
# 958:	learn: 0.0040956	total: 7m 52s	remaining: 20.2s
# 959:	learn: 0.0040898	total: 7m 53s	remaining: 19.7s
# 960:	learn: 0.0040889	total: 7m 53s	remaining: 19.2s
# 961:	learn: 0.0040857	total: 7m 54s	remaining: 18.7s
# 962:	learn: 0.0040842	total: 7m 54s	remaining: 18.2s
# 963:	learn: 0.0040835	total: 7m 55s	remaining: 17.7s
# 964:	learn: 0.0040821	total: 7m 55s	remaining: 17.3s
# 965:	learn: 0.0040807	total: 7m 56s	remaining: 16.8s
# 966:	learn: 0.0040797	total: 7m 56s	remaining: 16.3s
# 967:	learn: 0.0040724	total: 7m 57s	remaining: 15.8s
# 968:	learn: 0.0040664	total: 7m 57s	remaining: 15.3s
# 969:	learn: 0.0040647	total: 7m 58s	remaining: 14.8s
# 970:	learn: 0.0040640	total: 7m 58s	remaining: 14.3s
# 971:	learn: 0.0040633	total: 7m 59s	remaining: 13.8s
# 972:	learn: 0.0040527	total: 7m 59s	remaining: 13.3s
# 973:	learn: 0.0040508	total: 8m	remaining: 12.8s
# 974:	learn: 0.0040464	total: 8m	remaining: 12.3s
# 975:	learn: 0.0040418	total: 8m 1s	remaining: 11.8s
# 976:	learn: 0.0040403	total: 8m 1s	remaining: 11.3s
# 977:	learn: 0.0040387	total: 8m 2s	remaining: 10.8s
# 978:	learn: 0.0040342	total: 8m 2s	remaining: 10.4s
# 979:	learn: 0.0040295	total: 8m 3s	remaining: 9.86s
# 980:	learn: 0.0040289	total: 8m 3s	remaining: 9.37s
# 981:	learn: 0.0040282	total: 8m 4s	remaining: 8.87s
# 982:	learn: 0.0040276	total: 8m 4s	remaining: 8.38s
# 983:	learn: 0.0040225	total: 8m 5s	remaining: 7.89s
# 984:	learn: 0.0040211	total: 8m 5s	remaining: 7.39s
# 985:	learn: 0.0040131	total: 8m 6s	remaining: 6.9s
# 986:	learn: 0.0040124	total: 8m 6s	remaining: 6.41s
# 987:	learn: 0.0040066	total: 8m 6s	remaining: 5.91s
# 988:	learn: 0.0040030	total: 8m 7s	remaining: 5.42s
# 989:	learn: 0.0040021	total: 8m 7s	remaining: 4.93s
# 990:	learn: 0.0040008	total: 8m 8s	remaining: 4.44s
# 991:	learn: 0.0039997	total: 8m 9s	remaining: 3.94s
# 992:	learn: 0.0039976	total: 8m 9s	remaining: 3.45s
# 993:	learn: 0.0039969	total: 8m 10s	remaining: 2.96s
# 994:	learn: 0.0039957	total: 8m 10s	remaining: 2.47s
# 995:	learn: 0.0039945	total: 8m 11s	remaining: 1.97s
# 996:	learn: 0.0039847	total: 8m 12s	remaining: 1.48s
# 997:	learn: 0.0039837	total: 8m 13s	remaining: 988ms
# 998:	learn: 0.0039764	total: 8m 14s	remaining: 495ms
# 999:	learn: 0.0039753	total: 8m 15s	remaining: 0us

# %%
model.save_model('catboost_model')

# %%
y_test_pred = model.predict(X_test)

# %%
def eval_metric(test, train):
    f1 = f1_score(test, train)
    precision = precision_score(test, train)
    recall = recall_score(test, train)
    print (f"f1: {f1}\nprecision: {precision}\nrecall: {recall}")

# %%
eval_metric(y_test, y_test_pred)
# Out:
# f1: 0.9152046783625731
# precision: 0.9842767295597484
# recall: 0.855191256830601

# %% [markdown]
# ## NetworkX
# Get all the connected components

# %%
df_connected = df[df.is_duplicate==1]

# %%
df_connected.head()
# Out:
#                                                 name_1  \
# pair_id
# 162      jx nippon oil & gas exploration (brasil) ltda
# 604                        pirelli neumaticos s.a.i.c.
# 836                      brenntag australia (pty) ltd.
# 1329            paul bauder gmbh & co kg, bochum plant
# 1563                      total ceska republika s.r.o.
#
#                                                     name_2  is_duplicate
# pair_id
# 162      jx nippon oil & gas exploration technical serv...             1
# 604                                 pirelli tyre co., ltd.             1
# 836                                         brenntag group             1
# 1329                                        paul bauder ag             1
# 1563                           total france (arnay le duc)             1

# %%
G = nx.Graph()
G.add_edges_from(df_connected[['name_1','name_2']].to_numpy().tolist())
conn_comp_lst = list(nx.connected_components(G))

# %%
with open("conn_comp", "wb") as fp:
    pickle.dump(conn_comp_lst, fp)

# %% [markdown]
# ## Matching the input company name with the group

# %%
def match_company(model, veczr, connected_components_list, input_name):
    predict_lst = []
    for group in tqdm(connected_components_list):
        group_lst = [input_name] * len(list(group))
        input_vec = veczr.transform(group_lst)
        group_vec = veczr.transform(list(group))
        summ = input_vec + group_vec
        predict_lst.append(model.predict_proba(summ)[:,1].mean())
    max_idx = predict_lst.index(max(predict_lst))

    return connected_components_list[max_idx]

# %%
input_name = 'jx nippon oil & gas exploration'
match_company(model, tfidf_veczr, conn_comp_lst, input_name)
# Out:
# 100%|██████████| 441/441 [13:11<00:00,  1.79s/it]
# {'ooo"guchchi rus"'}

# %%
conn_comp_lst
# Out:
# [{'china southern petroleum exploration and development corporation',
#   'jx nippon oil & gas exploration (brasil) ltda',
#   'jx nippon oil & gas exploration (malaysia) limited',
#   'jx nippon oil & gas exploration (myanmar) limited',
#   'jx nippon oil & gas exploration (qatar) limited',
#   'jx nippon oil & gas exploration (sarawak), ltd',
#   'jx nippon oil & gas exploration australia pty ltd.',
#   'jx nippon oil & gas exploration corporation',
#   'jx nippon oil & gas exploration technical services corporation',
#   'nippon oil exploration (sarawak) limited',
#   'nippon oil exploration limited',
#   'nippon oil exploration u.s.a. limited'},
#  {'pirelli de venezuela c.a.',
#   'pirelli neumaticos argentina sa',
#   'pirelli neumaticos s.a. de c.v.',
#   'pirelli neumaticos s.a. de cv',
#   'pirelli neumaticos s.a.i.c.',
#   'pirelli neumaticos sa',
#   'pirelli neumaticos sa de',
#   'pirelli neumaticos sa de cv boulev',
#   'pirelli neumaticos sa de cv.',
#   'pirelli pneus ltda',
#   'pirelli tire llc',
#   'pirelli tyre co., ltd.'},
#  {'brenntag australia (pty) ltd.',
#   'brenntag chile comercial e ind',
#   'brenntag chile comercial e industrial ltda',
#   'brenntag colombia s.a.',
#   'brenntag ecuador s.a.',
#   'brenntag group',
#   'brenntag ingredients inc.',
#   'brenntag mexico s.a. de c.v.',
#   'brenntag peru s.a.c.',
#   'brenntag vietnam co., ltd.'},
#  {'paul bauder ag',
#   'paul bauder gmbh & co kg',
#   'paul bauder gmbh & co kg, bochum plant',
#   'paul bauder gmbh & co kg, landsberg plant',
#   'paul bauder gmbh & co kg, stuttgart plant',
#   'paul bauder gmbh & co. kg',
#   'paul bauder gmbh & co.kg, achim plant'},
#  {'total bitumen deutschland gmbh',
#   'total bitumen gmbh',
#   'total bitumen*',
#   'total ceska republika s.r.o.',
#   'total czech republic',
#   'total france (arnay le duc)',
#   'total petrochemicals france',
#   'total petrochemicals france sa',
#   'total polska',
#   'total polska sp. z o.o.',
#   'total romania s.a.',
#   'total rumunia'},
#  {'bridgestone (china) research and development co., ltd.',
#   'bridgestone (huizhou) tire co., ltd.',
#   'bridgestone (tianjin) tire co., ltd.',
#   'bridgestone americas tire',
#   'bridgestone canada inc.',
#   'bridgestone de costa rica s.a.',
#   'bridgestone de costa rica sociedad anoni',
#   'bridgestone de mexico s.a. de c.v.',
#   'bridgestone do brasil industria & comercio ltda',
#   'bridgestone do brasil industria e comenrcio ltda',
#   'bridgestone do brasil industria e comercio ltda',
#   'bridgestone firestone de argentina saic',
#   'bridgestone firestone de mexico sa de cv',
#   'bridgestone firestone do brasil',
#   'bridgestone firestone venezolana',
#   'bridgestone firestone venezolana c',
#   'bridgestone golf (shenzhen) co., ltd.',
#   'bridgestone hosepower llc',
#   'bridgestone india',
#   'bridgestone india automotive',
#   'bridgestone india automotive products private ltd.',
#   'bridgestone india pvt., ltd.',
#   'bridgestone international group',
#   'bridgestone ncr',
#   'bridgestone neumaticos de',
#   'bridgestone neumaticos de monterreysa de cv',
#   'bridgestone stargard sp zoo',
#   'bridgestone tire',
#   'bridgestone tire co.',
#   'bridgestone （huizhou）synthetic rubber co., ltd.',
#   'bridgestone(shenyang) tire co., ltd.',
#   'pt bridgestone tire indonesia',
#   'shenyang bridgestone',
#   'thai bridgestone co., ltd.',
#   'warren plant bato bridgestone'},
#  {'carlisle coatings & waterproofing, inc.', 'carlisle coatings & wtrprfng'},
#  {'ondulin',
#   'onduline polska sp. z o.o.',
#   'onduline s.a.',
#   'onduline us plants/ onduline north america inc'},
#  {'rhino rugby',
#   'rhino rugby france',
#   'rhino rugby ltd.',
#   'rhino rugby south africa (pty) ltd.'},
#  {'sumitomo bakelite (nantong) co., ltd.',
#   'sumitomo chemical do brasil representacoes limitada',
#   'sumitomo corp. of america',
#   'sumitomo corporation do brasil sa',
#   'sumitomo corporation of america',
#   'sumitomo industrias pesadas do brasil ltda',
#   'sumitomo rubber (changshu) co., ltd.',
#   'sumitomo rubber do brasil ltda',
#   'sumitomo rubber inds',
#   'sumitomo rubber industries',
#   'sumitomo rubber industries usa',
#   'sumitomo rubber industriesusa',
#   'sumitomo rubber north america inc.',
#   'sumitomo rubber usa 10 sheridan',
#   'sumitomo rubber usa llc',
#   'sumitomo rubber(hunan) co. ltd.',
#   'sumitomo warehouse (usa.) inc.'},
#  {'basf (china) co., ltd. shanghai',
#   'basf auxiliary chemicals',
#   'basf bangladesh ltd.',
#   'basf chile s a',
#   'basf chile s.a.',
#   'basf co., ltd.',
#   'basf co., ltd. yeosu',
#   'basf colors & effects usa llc',
#   'basf construction chemicals',
#   'basf construction chemicals ua',
#   'basf corp.',
#   'basf corporation',
#   'basf de costa rica sociedad anonima',
#   'basf finlay pvt., ltd.',
#   'basf india',
#   'basf india ltd.',
#   'basf japan ltd.',
#   'basf japan ltd. 6 10 1 roppongi',
#   'basf mexicana s.a. de c.v.',
#   'basf new zealand ltd.',
#   'basf pakistan (private) ltd.',
#   'basf pakistan ltd.',
#   'basf peruana s.a.',
#   'basf quimica colombiana s.a.',
#   'basf sa',
#   'basf turk kimya san ve tic.tld.sti',
#   'basf turk kimya san. ve tic.sti',
#   'basf turk kimya san.ve tic ltd.sti',
#   "basf's paper chemicals (huizhou) co., ltd.",
#   'bdp international basf imp.'},
#  {'himinvest grupp, ooo', 'ooo himinvest grupp'},
#  {'ibaraki zeon kasei co.,ltd.',
#   'zeon',
#   'zeon (shanghai) co. ltd.',
#   'zeon (shanghai) co., ltd.',
#   'zeon advance polymix co., ltd.',
#   'zeon advanced polymix co., ltd.',
#   'zeon asia malaysia sdn. bhd.',
#   'zeon asia pte ltd',
#   'zeon belts private ltd.',
#   'zeon chemicals (thailand) co., ltd',
#   'zeon chemicals europe limited',
#   'zeon chemicals l p',
#   'zeon chemicals l.p.',
#   'zeon chemicals yonezawa co.,ltd.',
#   'zeon corporation',
#   'zeon corporation (tse:4205)',
#   'zeon csc corporation',
#   'zeon do brasil ltda',
#   'zeon europe gmbh',
#   'zeon f&b co., ltd',
#   'zeon france',
#   'zeon india private limited',
#   'zeon italia srl',
#   'zeon kasei (changshu) co.,ltd',
#   'zeon kasei co., ltd.',
#   'zeon kasei mexico s.a. de c.v.',
#   'zeon korea co., ltd',
#   'zeon logistical materials co.,ltd.',
#   'zeon manufacturing vietnam co., ltd',
#   'zeon medical (guangzhou) inc',
#   'zeon medical inc.',
#   'zeon nano technology co., ltd',
#   'zeon north co., ltd.',
#   'zeon polymix incorporation',
#   'zeon produtos quimicos do brasil ltda',
#   'zeon research vietnam co., ltd',
#   'zeon rim co., ltd',
#   'zeon shinhwa (zeshin) inc.',
#   'zeon specialty materials inc.',
#   'zeon trading (shanghai) co., ltd.',
#   'zeon trading （shanghai）co. ltd.',
#   'zs elastomers co., ltd.'},
#  {'dow chemical',
#   'dow chemical (shanghai) co., ltd.',
#   'dow chemical international private ltd.',
#   'dow chemical pacific',
#   'dow chemical pacific ltd.',
#   'dow chemical thailand ltd.',
#   'dow international mexicana s.a. de',
#   'dow international mexicana sa de cv',
#   'dow quimica mexicana sa cv'},
#  {'cebu toyo corp',
#   'shanghai toyo ink mfg. co., ltd.',
#   'toyo tire north',
#   'toyo tire north america',
#   'toyo tires zhangjiagang co., ltd.',
#   'toyo trans inc.',
#   'zhuhai toyo ink co., ltd.'},
#  {'arlanxeo',
#   'arlanxeo brasil sa',
#   'arlanxeo canada inc.',
#   'arlanxeo corp.',
#   'arlanxeo international group',
#   'arlanxeo singapore pte.',
#   'arlanxeo singapore pte. lt',
#   'arlanxeo singapore pte., ltd.',
#   'arlanxeo singapore pte., ltd. tearlanxeo canada inc. 1265 vidal',
#   'arlanxeo usa llc',
#   'ktn underwood arlanxeo usa llc'},
#  {'c.o.i.m. s.p.a.',
#   'c.o.i.m. s.p.a. chimica organica industriale milanese',
#   'coim s.p.a.'},
#  {'ooo"import moda"'},
#  {'diesel fashion india reliance private ltd.',
#   'marks and spencer reliance india pvt., ltd.',
#   'reliance bally india private ltd.',
#   'reliance brands',
#   'reliance chemical products ltd.',
#   'reliance clothing india private ltd.',
#   'reliance commcl dealers',
#   'reliance industries ltd.',
#   'reliance lifestyle holding',
#   'reliance luxury fashion private ltd.',
#   'reliance paul & shark fashions pvt., ltd.',
#   'reliance retail ltd.',
#   'reliance sibur elastomers pvt., ltd.',
#   'reliance spg mills ltd.',
#   'ryohin keikaku reliance india private ltd.'},
#  {'savino del bene',
#   'savino del bene chile s.a.',
#   'savino del bene poland sp. z o.o.',
#   'savino del bene usa inc.'},
#  {'gestion soprema canada inc.',
#   'soprema',
#   'soprema alpiarca',
#   'soprema blonie',
#   'soprema canada',
#   'soprema castellbisbal',
#   'soprema chilliwack',
#   'soprema drummondville',
#   'soprema gmbh',
#   'soprema grobbendonk',
#   'soprema iberia',
#   'soprema iberia s.l.',
#   'soprema nv',
#   'soprema oberrossbach',
#   'soprema polska sp z o o',
#   'soprema polska sp. z o.o.',
#   'soprema s.a.',
#   'soprema s.a.s.',
#   'soprema s.r.l.',
#   'soprema salgareda',
#   'soprema sas',
#   'soprema soprema sas',
#   'soprema sourges',
#   'soprema, s.a.'},
#  {'ooo "soudal"', 'soudal', 'soudal n.v.', 'soudal nv', 'soudal nv by'},
#  {'pt sika indonesia',
#   'sika (cambodia) ltd.',
#   'sika (cambodia) ltd. warehouse',
#   'sika (china) ltd.',
#   'sika (singapore) pte., ltd.',
#   'sika colombia s.a.',
#   'sika corporation',
#   'sika india private ltd.',
#   'sika kimia sdn. bhd.',
#   'sika lanka (pvt) ltd.',
#   'sika ltd. (vietnam)',
#   'sika mexicana s.a. de c.v.',
#   'sika pakistan (pvt) ltd.',
#   'sika s a.',
#   'sika s.a. chile',
#   'sika sa',
#   'sika thailand'},
#  {'m.f.p. michelin',
#   'michelin (shenyang) tyre co., ltd.',
#   'michelin aircraft tire',
#   'michelin americas research',
#   'michelin espana portugal sa',
#   'michelin group',
#   'michelin india private ltd.',
#   'michelin india tamilnadu tyres private ltd.',
#   'michelin india technology center',
#   'michelin india technology center llp',
#   'michelin na asrc',
#   'michelin north america (canada) inc.',
#   'michelin north america inc.',
#   'michelin research and development center (shanghai) co., ltd.',
#   'michelin shenyang tire co., ltd.',
#   'michelin siam co., ltd.',
#   'michelin tyre plc',
#   'shanghai michelin tire co., ltd.',
#   'shanghai michelin warrior tyre co., ltd.',
#   'sociedade michelin de participacoes ind e comercio ltda',
#   'sociedade michelin de participacoes indust e comercio l'},
#  {'midland asphalt', 'midland asphalt materials inc'},
#  {'yokohama',
#   'yokohama corp. of north ameri',
#   'yokohama india pvt., ltd.',
#   'yokohama industries americas',
#   'yokohama re mfg.',
#   'yokohama rubber co., ltd. the',
#   'yokohama tire canada',
#   'yokohama tire corp.',
#   'yokohama tire corporation',
#   'yokohama tire mfg. virgini',
#   'yokohama tyre'},
#  {'giti radial tire (anhui) co.',
#   'giti tire (hualin) co., ltd.',
#   'giti tire (usa) ltd.',
#   'giti tire mfg.',
#   'giti tire mfg. (usa)',
#   'giti tire mfg. (usa) ltd.',
#   'giti tire mfg. l.t.d.'},
#  {'goter',
#   'goter (italija)',
#   'goter s.r.l.',
#   'goter thermoplastic compounds s.p.a',
#   'goter thermoplastic compounds spa'},
#  {'owens corning',
#   'owens corning (nyse:oc)',
#   'owens corning glass metal services',
#   'owens corning ht, inc.',
#   'owens corning insulating systems, llc',
#   'owens corning sales l l c',
#   'owens corning sales llc',
#   'owens corning, masonry products business'},
#  {'gates corporation', 'gates usa'},
#  {'flex sol',
#   'flex?computing?(suzhou) ?co.,? ltd.',
#   'hansa flex usa',
#   'k flex india private ltd.',
#   'k flex usa',
#   'k flex usa llc. 100 nomaco',
#   "l'isolante k-flex spa",
#   'lisolante k-flex spa',
#   'nichirin flex u . s . a . inc.',
#   'nitro flex x s.a.c.',
#   'planika flex d.o.o'},
#  {'ajko',
#   'iko',
#   'iko eu /all plants*',
#   'iko europe',
#   'iko sales',
#   'iko sas',
#   'iko slovakia',
#   'iko slovakia, s.r.o.'},
#  {'power adhesives', 'power adhesives ltd'},
#  {'kraton polymers do brasil sa',
#   'kraton polymers japan ltd.',
#   'kraton polymers nederland bv',
#   'kraton polymers trading shanghai co., ltd.',
#   'kraton polymers us',
#   'kraton polymers us llc',
#   'kraton polymers us llc.',
#   'kraton polymers us. llc'},
#  {'bit mat. products of michigan, inc.',
#   'bit-mat products',
#   'bit-mat products of indiana, inc.',
#   'klink group'},
#  {'alpha trading', 'alpha trading s.p.a'},
#  {'shanghai synthomer chemicals co., ltd.',
#   'synthomer (uk) ltd.',
#   'synthomer llc',
#   'synthomer llc c oterminal',
#   'synthomer llc c oterminal warehouse',
#   'synthomer llc. peachtree lenox bl bonded logistics 7320 statesville',
#   'synthomer ltd.',
#   'synthomer srl'},
#  {'versalis americas inc.',
#   'versalis pacific trading (shanghai)',
#   'versalis pacific trading shanghai',
#   'versalis sp a'},
#  {'onur taahhut tasimacilik insaat ticaret ve sanayi as',
#   'onur taahhut tasimacilik ve ticaret ltd sti',
#   'onur taahhüt '},
#  {'ineos oligomers',
#   'ineos styrolution america llc',
#   'ineos styrolution do brasil polimeros ltda',
#   'ineos styrolution india ltd.',
#   'ineos usa llc'},
#  {'ooo"guchchi rus"'},
#  {'dunlop slazenger international inc.', 'fenner dunlop americas'},
#  {'saint gobain canada inc.',
#   'saint gobain colombia sas',
#   'saint gobain india pvt., ltd.',
#   'saint gobain performance plastics',
#   'saint gobain vietnam co., ltd.'},
#  {'petro-canada (international) holdings bv',
#   'petro-canada denmark gmbh',
#   'petro-canada energy north sea limited',
#   'petro-canada oil sands inc.',
#   'petro-canada resources (usa) inc.',
#   'petro. canada'},
#  {'naftna industrija srbije',
#   'naftna industrija srbije a.d. (belex:niis)',
#   'nis ( gpn subcidiary)'},
#  {'lohmann gmbh & co. kg'},
#  {'kenda farben india pvt., ltd.',
#   'kenda rubber (china) co., ltd.',
#   'kenda rubber (tianjin) co., ltd.',
#   'kenda rubber industries co., ltd.',
#   'pt . kenda rubber indonesia'},
#  {'exxonmobil asia pacific r & d co., ltd.',
#   'exxonmobil chemical americas 22777 springwoods village parkway',
#   'exxonmobil chemical americas on',
#   'exxonmobil chemical americas po box 4549 houston',
#   'exxonmobil chemical asia pacific',
#   'exxonmobil chemical co.',
#   'exxonmobil chemical co. baytown chemical plant',
#   'exxonmobil japan godo kaisha',
#   'exxonmobil petroleum and chemical',
#   'exxonmobil quimica ltda',
#   'exxonmobil servicios petroleros mexico sa de cv'},
#  {'bofer insaat aluminium san. ve tic. ltd. sti', 'ooo"boffer"'},
#  {'pavimental', 'pavimental s.p.a.'},
#  {'a.p.i.',
#   'a.p.i. applicazioni plastiche industriali s.p.a.',
#   'a.p.i. applicazioni plastiche industriali spa',
#   'api',
#   'trinseo api'},
#  {'contitech antriebssysteme gmb h',
#   'contitech australia (pty) ltd.',
#   'contitech chile s.a.',
#   'contitech chile sa',
#   'contitech fluid mexicana sa de cv',
#   'contitech india private ltd.',
#   'contitech mexicana sa de cv',
#   'contitech transportbandsysteme gmb h',
#   'contitech usa inc.'},
#  {'beijing oriental yuhong waterproof technology co., ltd. (szse:002271) - 北京东方雨虹防水技术股份有限公司',
#   'oriental yuhong'},
#  {'ankara insaat',
#   'ankara insaat ticaret ve sanayi limited sirketi',
#   'ankara i̇nşaat '},
#  {'obo bettermann produktion deutschland gmbh & co.kg',
#   'obo bettermann produktion deutschland gmbh & co.kg/revival express chop (ua)',
#   'ooo "obo bettermann"',
#   'ooo"obo bettermann"'},
#  {'mogat',
#   'mogat-werke adolf boving bitumen- und dachpappenfabrik gesellschaft mit beschrankter haftung',
#   'mogat-werke adolf böving bitumen- und dachpappen fabrik gmbh'},
#  {'appia liants ouest', 'appia liants ouest ( alo)'},
#  {'h & v advanced materials india pvt., ltd.',
#   'h & v advanced materials(india) pvt., ltd.'},
#  {'trinseo europe gmb h tax id be0806160466',
#   'trinseo europe gmb h trade register 20162359',
#   'trinseo europe gmb h trade register 20162359 tax id be0806160466',
#   'trinseo europe gmb h vat id nl819885150 b01',
#   'trinseo llc',
#   'trinseo llc (us)'},
#  {'tuermerleim', 'turmerleim gmbh', 'türmerleim gmbh'},
#  {'del corona & scardigli mexico', 'del corona & scardigli usa'},
#  {'filial kompanii ekson neftegaz limited',
#   'filial kompanii"ekson neftegaz limited"'},
#  {'dorken gmbh. & co. kg', 'ooo"derken"'},
#  {'bharat adhesives',
#   'bharat bijlee ltd.',
#   'bharat electronics ltd.',
#   'bharat enterprises',
#   'bharat heavy electricals ltd.',
#   'bharat polymers',
#   'bharat rubber works pvt., ltd.'},
#  {'poliglas', 'polyglass', 'polyglass america (mapei)', 'polyglass s.p.a.'},
#  {'joss', 'joss elastomers & chemicals b.v.', 'joss holding b.v.'},
#  {'ooo"privat trejd"'},
#  {'afton chemical de mexicosa de cv',
#   'afton chemical hyderabad pvt., ltd.',
#   'afton chemical india private ltd.',
#   'afton chemical industria de aditivos ltda'},
#  {'agip',
#   'agip  ( eni group)',
#   'agip spa',
#   'azienda generale italiana petroli'},
#  {'sumika polymers mexico s de rl de cv',
#   'sumika polymers north america',
#   'sumika polymers north america inc.'},
#  {'indian synthetic rubber ltd.',
#   'indian synthetic rubber private ltd.',
#   'indian synthetic rubber pvt., ltd.'},
#  {'daewoo international (america) corp.',
#   'daewoo international corp.',
#   'daewoo paper mfg.cd. ltd.',
#   'daewoo spinning mills',
#   'fc daewoo textile llc',
#   'posco daewoo (america) corp.',
#   'posco daewoo america corp.',
#   'posco daewoo america corp. toronto b',
#   'posco daewoo corporation'},
#  {'varo energy', 'varo energy b.v.'},
#  {'evonik corp.',
#   'evonik corporation c/o stockhausen',
#   'evonik cryo llc',
#   'evonik cyro llc',
#   'evonik cyro llc mobile',
#   'evonik degussa brasil ltda',
#   'evonik india'},
#  {'binne',
#   'binne & sohn gmbh & co kg',
#   'binné & sohn gmbh & co. kg dachbaustoffwerk'},
#  {'ooo"orak"', 'orac n.v.'},
#  {'showa rekisei',
#   'showa rekisei industries co.,ltd.',
#   'showa shell',
#   'showa shell sekiyu k.k.'},
#  {'wakol', 'wakol gmbh'},
#  {'dupont (korea) inc.',
#   'dupont apollo (shenzhen) ltd.',
#   'dupont do brasil sa',
#   'dupont mexico',
#   'dupont nutrition usa inc.c o ceva',
#   'dupont specialty products usa llc',
#   'dupont teijin films',
#   'e.i.dupont de nemours & co. inc.'},
#  {'ford ieo',
#   'ford werke gmbh',
#   'obschestvo s ogranichennoj otvetstvennost\'ju "ford sollers elabuga"'},
#  {'dow brasil industria & comercio de produtos quimicos lt',
#   'dow brasil industria e comercio de produtos quimicos lt',
#   'dow brasil sudeste industrial ltda',
#   'dow silicones corp.',
#   'dow silicones corp. plant'},
#  {'swisspor (vaparoid)', 'swisspor polska', 'swisspor polska sp. z o.o.'},
#  {'evobus gmbh ersatzteillogistic-center', 'ooo "evobus russlend"'},
#  {'quandt dachbahnen',
#   'w. quandt dachbahnen und dachstoffe gmbh',
#   'w. quandt gmbh & co. kg'},
#  {'ooo"spetsial\'noe oborudovanie"'},
#  {'marathon', 'marathon oil corporation (nyse:mro)'},
#  {'p.group so.f.ter. deutschland gmbh',
#   'so.f.ter.',
#   'so.f.ter. s.r.l',
#   'softer / celanese'},
#  {'tremco illbruck / rpm', 'tremco illbruck group gmbh'},
#  {'automotive performance material',
#   'automotive performance material (apm)',
#   'automotive performance materials'},
#  {'hp pelzer s.r.o.', 'ooo "hp pel\'tser rus"'},
#  {'mondi', 'mondi limited', 'mondi scunthorpe limited', 'mondi styria gmbh'},
#  {'parker hannifin canada division', 'parker hannifin distribution center'},
#  {'dow europe gmb h', 'dow europe gmb h plant f208'},
#  {'assa', 'assa roofing solutions'},
#  {'rhino sport and leisure', 'rhino sports + leisure llc'},
#  {'icopal', 'icopal kft.'},
#  {'three bond europe', 'three bond europe s.a.'},
#  {'eurovia cs',
#   'eurovia czechy',
#   'eurovia polska',
#   'eurovia polska s a',
#   'eurovia vinci'},
#  {'rhenocoll-werk', 'rhenocoll-werk e.k.'},
#  {'termocompo',
#   'termocompo - industria termoplastica, lda',
#   'termocompo - indústria termoplástica, lda'},
#  {'probisa',
#   'probisa productos bituminosos',
#   'probisa productos bituminosos s.l.u.'},
#  {'eneos globe corporation', 'eneos globe energy co., ltd.'},
#  {'delta acm', 'delta roofing, inc.'},
#  {'ravago distribution sa',
#   'ravago group',
#   'ravago ltd. (hk)',
#   'ravago mfg. india private ltd.',
#   'ravago shah polymers pvt., ltd.'},
#  {'danis yapi madencilik sanayi ve ticaret anonim sirketi', 'daniş yapi '},
#  {'dalpo', 'dalpo poznan sp z o o spolka komandytowa', 'dalpo sp. z o.o.'},
#  {'kimberly-clark (nanjing) care products co., ltd.',
#   'kimberly-clark europe ltd',
#   'ooo "kimberli-klark"'},
#  {'lectra s.a.', 'lectra sa', 'ooo"lektra russland"'},
#  {'buhler ag', 'ooo"bjuler servis"'},
#  {'industrias negromex ', 'negromex'},
#  {'makyol',
#   'makyol insaat sanayi turizm ve ticaret a s',
#   'makyol insaat sanayi turizm ve ticaret a.s.'},
#  {'kimberly-clark', 'kimberly-clark ', 'ooo"kimberli-klark"'},
#  {'omv aktiengesellschaft',
#   'omv aktiengesellschaft (wbag:omv)',
#   'omv all plants'},
#  {'compogal', 'kompogal'},
#  {'superbeton', 'superbeton s.p.a.'},
#  {'vedag', 'vedag gmbh (bamberg)'},
#  {'freudenberg nok componentes brasil ltda',
#   'freudenberg nok de mexico sa de cv',
#   'freudenberg nok pvt., ltd.'},
#  {'ter group gmbh', 'ter hell & co. gmbh', 'ter hell or strabeq'},
#  {'ooo"essiej hajdzhin prodakts rasha svetogorskij filial',
#   'ooo"essiej hajdzhin prodakts rasha"'},
#  {'lagan bitumen limited', 'lagan bitumen ltd'},
#  {'sanyhot', 'sanyhot adhesivos'},
#  {'alibesa',
#   'andaluza de ligante bituminosos y betunes s.a.',
#   'andaluza de ligantes bituminosos y betunes sa (en liquidacion)'},
#  {'jiangsu canlon building materials',
#   'jiangsu canlon building materials co., ltd.'},
#  {'forbo eurocol deutschland gmbh', 'ooo "forbo evrokol rus"'},
#  {'wright asphalt products',
#   'wright asphalt products co.',
#   'wright asphalt products company llc'},
#  {'auriquimica ltda', 'auriquimica ltda cnpj', 'auriquimica ltda filial'},
#  {'lotos asfalt', 'lotos asfalt sp. z o.o.'},
#  {'konimpeks', 'konimpex'},
#  {'vebel s.r.l.', 'verel srl'},
#  {'ceva freight llc',
#   'ceva freight management',
#   'ceva freight management mexico'},
#  {'adriatica bitumi', 'adriatica bitumi s.p.a.', 'adriatica bitumi spa'},
#  {'bituver',
#   'isover saint-gobain',
#   'saint-gobain',
#   'saint-gobain corporation',
#   'saint-gobain isover austria gmbh'},
#  {'sabic innovative plastics mexico s.', 'sabic innovative plastics us llc'},
#  {'ikea distribution service(shanghai)',
#   'ikea distribution services',
#   'ikea distribution services gmb h'},
#  {'grisard', 'grisard ag'},
#  {'huesker synthetic gmbh', 'ooo"hjusker"'},
#  {'technonikol', 'technonikol ', 'technonikol ltd.'},
#  {' so.f.ter. spa', 'softer us inc.'},
#  {'michelin',
#   'michelin hungaria kft',
#   'michelin hungaria tyre manufacture ltd',
#   'michelin polska,simorep et cie,simorep & cie',
#   'michelin reifenwerke ag & co kgaa',
#   'michelin tires',
#   'mishlen'},
#  {'porr', 'porr ag'},
#  {'isolago - indústria de plásticos s.a.', 'isolago s.a.'},
#  {'hubei guochuang hi-tech material',
#   'hubei guochuang hi-tech material co.,ltd (szse:002377)',
#   'hubei guochuang hi-tech material in'},
#  {'k-flex polska sp. z.o.o."', 'ooo "k-fleks"'},
#  {'ooo "selena vostok"', 'selena fm s.a.'},
#  {'kerabit', 'kerabitpro oy'},
#  {'m. holland co.', 'm.holland co.'},
#  {'pafra adhesives limited', 'pafra adhesives ltd '},
#  {'bulmarket dm ', 'bulmarket dm ltd.'},
#  {'biesterfeld plastic gmbh',
#   'ooo "bisterfel\'d rus"',
#   'ooo"bisterfel\'d rus"'},
#  {'spc europe limited', 'spc spain ', 'spc-jevsa slu'},
#  {'danisco (china) co., ltd.', 'danisco (india) pvt., ltd.'},
#  {'maxwell',
#   'maxwell polymers llp',
#   'vetus & maxwell marine india pvt., ltd.'},
#  {'eiffage', 'eiffage construction alpes dauphine', 'eiffage sa (enxtpa:fgr)'},
#  {'indian overseas bank', 'indian oxides and chemicals private ltd.'},
#  {'kuraray america inc.',
#   'kuraray india private ltd.',
#   'kuraray mexico s. de r.l. de c.v.'},
#  {'inreco - emulsja sp. z o.o.', 'inreco emulsje'},
#  {'ooo «poliplast novomoskovsk»',
#   'ooo «poliplast severo-zapad»',
#   'ooo «poliplast-uralsib»',
#   '«gk poliplast» '},
#  {'omür taban', 'ömür taban'},
#  {'bodo moller chemie gmbh', 'ooo "bodo meller hemi russija"'},
#  {'goodyear ', 'goodyear chemical co', 'the goodyear tire and rubber company'},
#  {'synthos',
#   'synthos dwory 7 spolka',
#   'synthos dwory sa',
#   'synthos kralupy',
#   'synthos rubber'},
#  {'w. r. grace canada corp', 'wrgrace', 'wrgrace & co. of canada ltd.'},
#  {'ooo "rehau produktsion"', 'ooo "rehau"', 'rehau ag+co'},
#  {'super beton', 'super beton ltd.'},
#  {'binex line corp.',
#   'binex line corp. chicago',
#   'binex line corp. seattle',
#   'binex line corp. vancouver'},
#  {'fragmat', 'fragmat tim d.d.', 'fragmat tim d.o.o.'},
#  {'thuan loi rubber', 'thuan loi rubber co., ltd.'},
#  {'isoliererzeugnisse grobrohrsdorf gmbh',
#   'isoliererzeugnisse grossröhrsdorf gmbh'},
#  {'cdi energy products  divison of fenner advanced sealing technologies',
#   'fenner advanced sealing technologies, inc.',
#   'fenner drives, inc.',
#   'fenner dunlop (atlanta), inc.',
#   'fenner dunlop (charlotte) inc.',
#   'fenner dunlop (toledo), llc',
#   'fenner dunlop holdings, inc.',
#   'fenner precision, inc.',
#   'fenner usa'},
#  {'bal taban',
#   'bal taban granul ayakkabicilik sanayi ve ticaret limited sirketi,'},
#  {'multibase', 'multibase inc.'},
#  {'anser sp.z o.o', 'zaklady chemiczne anser sp. z o.o.'},
#  {'parker hannifin', 'parker hannifin usa'},
#  {'mitsui & co (canada)', 'mitsui & co usa inc.', 'mitsui & co., ltd.'},
#  {'eterna s a', 'eterna s.a.'},
#  {'general electric plastics gmbh', 'general electric plastics italia srl'},
#  {'ravago', 'ravago sa'},
#  {'kumho petrochemical co., ltd.',
#   'kumho tire (tianjin) co., ltd.',
#   'kumho tire changchun co. inc.',
#   'kumho tire georgia inc.',
#   'kumho tire goergia inc.'},
#  {'old castle', 'oldcastle building products, inc.'},
#  {'probigalp', 'probigalp - ligantes betuminosos, s.a.'},
#  {'mondelez europe gmbh',
#   'mondelez polska production sp.z.o.o',
#   'ooo"mon\'delis rus\'"',
#   'ooo"mondelis rus\'"'},
#  {'ashland', 'ashland inc.', 'ashland specialty ingredients gp'},
#  {'dzhons mansvil', 'johns mansville'},
#  {'nexeo solutions europe b.v.', 'ooo"nekseo soljushens rus"'},
#  {'bst elastomers co.',
#   'japan synthetic rubber co',
#   'jsr america inc.',
#   'jsr bst elastomer',
#   'jsr corporation',
#   'jsr corporation (tse:4185)',
#   'jsr elastomer america inc.',
#   'jsr tradig inc.',
#   'ltd.'},
#  {'alfa laval lund ab', 'oao "al\'fa laval\' potok"'},
#  {'as tekni̇k mühendi̇sli̇k yapi ve yalitim malzemeleri̇ alümi̇nyum ve plasti̇k san. ti̇c. a.ş.',
#   'yalteks yalitim malzemeleri san. ve tic. a.ş',
#   'yalteks yalitim malzemeleri sanayi ve ticaret anonim sirketi'},
#  {'plastay group', 'plastay kimya', 'plastay kimya sanayi ve ticaret a s'},
#  {'michelin polska s.a.',
#   'ooo "mishlen russkaja kompanija po proizvodstvu shin"'},
#  {'ooo"favorit stajl'},
#  {'sodeks ag', 'sodex ag'},
#  {'taiwan synthetic rubber corp. ', 'tsrc', 'tsrc corporation'},
#  {'mondi osterburken gmbh',
#   'nordenia',
#   'nordenia deutschland osterburken gmbh'},
#  {'bitufa', 'bitufa waterproofing b.v.'},
#  {'huizhou lcy elastomers corp.', 'lcy elastomers lp'},
#  {'dynasol elastomeros sa de cv',
#   'dynasol llc',
#   'liaoning north dynasol synthetic rubber co., ltd.'},
#  {'dowdupont', 'dupont', 'the dow chemical company'},
#  {'abro industries, inc.', 'ooo "abro indastris"'},
#  {' alfagomma', 'alfagomma industrial spa'},
#  {'demo s.r.l.', 'ooo"demo"'},
#  {'eosso brothers, inc', 'esso'},
#  {'bitumenka', 'bitumenka d.d.'},
#  {'ooo"ozon gijim rsj"'},
#  {'ooo "paul\' hartmann"', 'paul hartmann ag'},
#  {'ooo "himmarket"'},
#  {'nizhnekamsk', 'nizhnekamskneftekhim', 'nknh', 'oao nizhnekamskneftekhim'},
#  {'sunflag (nigeria) ltd.',
#   'sunflag (tanzania) ltd.',
#   'sunflag nigeria ltd.',
#   'sunflag thailand ltd.'},
#  {'peretti bitumi', 'perretti petroli s.p.a.'},
#  {'lotte chemical corporation (kose:a011170)',
#   'lotte versalis elastomers co., ltd.'},
#  {'elastron kimya sanayi ve ticaret a.ş.',
#   'elastron kimya sanayi ve ticaret anonim sirketi'},
#  {'sumimoto', 'sumitomo chemical co.ltd.'},
#  {'univar chemicals (shanghai) co., ltd. /univar china ltd.',
#   'v.m. univar edison'},
#  {'jowat manufacturing (sea) sdn.bhd. no.25,lengkuk teknologi', 'ooo "jovat"'},
#  {'doppelmayr cable car gmbh & co. kg',
#   'doppelmayr seilbahnen gmbh',
#   'ooo"doppel\'majr rasha"'},
#  {'farmacap industria e comercio ltda',
#   'farmacap industries stria e com rcio ltda'},
#  {'k-flex usa', 'k-flex usa llc'},
#  {'celanese materials mexico', 'celanese operations mexico s de rl de cv'},
#  {'de boer green solutions nv', 'deboer schoten '},
#  {'hevea b.v.', 'hevea bv', 'heveachem international'},
#  {'ooo"vertikal\' sport"'},
#  {'bo9stic co.', 'bostic', 'bostik a/s'},
#  {'bochem / sudal',
#   'bochem sp. z o.o. zakłady chemiczne',
#   'zaklady chemiczne bochem sp. z.o.o.'},
#  {'tohpe corporation', 'tope seizo, k.k.'},
#  {'dynasol', 'dynasol elastomeros, s.a.u'},
#  {'continental automotive, inc.\xa0', 'kontinental automotive prodakts srl'},
#  {'tim izolirka ', 'tim izolirka d.o.o.'},
#  {'martin asphalt', 'martin asphalt co.'},
#  {'tokyo zairyo (india) private limited',
#   'tokyo zairyo (m) sdn bhd',
#   'tokyo zairyo (u.s.a.) inc.',
#   'tokyo zairyo co., ltd.'},
#  {'ao "tetra pak"', 'tetra pak technical service ab'},
#  {'aplix', 'aplix s.a.', 'sa aplix'},
#  {'prometeon tyre group industria brasil ltda', 'prometeon tyre group srl'},
#  {'netafim ltd.', 'ooo"netafim sng"'},
#  {'*** polimarket, ooo', 'ooo "polimarket"', 'ooo polimarket'},
#  {'gates fluid power technologies',
#   'gates fluid power technologies (changzhou) co., ltd.'},
#  {'celanese chemicals europe gmbh',
#   'celanese europe bv',
#   'celanese europe bv - ex softer'},
#  {'mitas a.s.', 'mitas tires north america'},
#  {'kkpc',
#   'kumho',
#   'kumho petrochemical',
#   'kumho petrochemical co., ltd. (kose:a011780)'},
#  {'pirelli tajr russija', 'pirelli tyre russia'},
#  {'duracell distributing inc.', 'duracell distributing inc.duracell'},
#  {"ozsahin sun'i kosele sanayii ve ticaret a s",
#   'ozsahin suni kosele sanayii ve ticaret anonim sirketi',
#   'özşahin a.ş'},
#  {'simge mat madencilik asfalt ticaret ve sanayi anonim sirketi', 'simge-mat'},
#  {'petro-canada cooperative holding ua', 'petro-canada resources (usa) inc'},
#  {'korea petroleum industries company (kose:a004090)',
#   'korea- ers- korea petroleum'},
#  {'interteks vorld resursis ink.', 'intertex world resources ltd.'},
#  {'mitsubishi chemical',
#   'mitsubishi chemical china commerce ltd.',
#   'mitsubishi chemical performance',
#   'mitsubishi electric india pvt., ltd.',
#   'mitsubishi gas chemical engineering plastics co., ltd.'},
#  {'jv ojsc uzkabel', "sp ao uzkabel'"},
#  {'delaval international ab', 'delaval international ab"', 'zao "delaval\'"'},
#  {'eni jr286 inc.',
#   'eni jr286 inc. (code 26 273374500)',
#   'eni shipping inc. houston'},
#  {'saint-gobain performance plastics corporation',
#   'saint-gobain performance plastics inc.'},
#  {'technovinyl polymers india limited',
#   'technovinyl polymers india ltd',
#   'technpvinyl polymers india ltd.'},
#  {'coco paving inc.', 'cocopaving'},
#  {'rompetrol', 'rompetrol rafinare s.a.'},
#  {'ooo"zanotti"', 'zanotti s.p.a"'},
#  {'crosspolimeri s.p.a.', 'crosspolimeri spa'},
#  {'goldenplast', 'goldenplast spa'},
#  {'bitumtec (former totalerg)', 'bitumtec s.r.l.', 'bitumtec srl'},
#  {'jowat se"',
#   'jowat se"/cherez terminal a.c."pol-sad",pol\'sha',
#   'jowat se"/cherez terminal v pol\'she',
#   'ooo"jovat"'},
#  {'colquimica', 'colquímica - indústria nacional de colas, s.a.'},
#  {'adi (salambo)', 'adi commerce', 'adi commerce ltd'},
#  {'gardner gibson', 'gardner gibson '},
#  {'arlanxeo ', 'arlanxeo brasil s.a.'},
#  {'rogitex', 'rogitex international inc.'},
#  {'orzel spolka akcyjna', 'orzel spolka akcyjna (wse:orl)', 'orzeł s.a. '},
#  {'albemarle corporation',
#   'albemarle corporation (nyse:alb)',
#   'albemarle green crest '},
#  {'gummiwerk kraiburg gmbh&co.kg', 'kraiburg bulgaria eood"', 'ooo"krajburg"'},
#  {'iko industries ltd.', 'iko midwest inc.'},
#  {'lg chem', 'lg chem ltd.', 'lgchem '},
#  {'general membrane', 'general membrane s.a.', 'general membrane s.p.a.'},
#  {'toa road', 'toa road corporation (tse:1882)'},
#  {'cts', 'cts corporation (nyse:cts)'},
#  {'knauf aquapanel gmbh & co. kg', 'ooo"knauf akvapanel\'"'},
#  {'avebe', 'avebe nederland b.v.'},
#  {'ooo "starkom"'},
#  {'rtl-inductives oy'},
#  {'gongguan heartychem co., ltd.', 'heartychem corp'},
#  {'ao"egor\'evsk-obuv\'"'},
#  {'versalis', 'versalis s.p.a. '},
#  {'kildair service ulc', 'kildair service, ltd.', 'kildair services'},
#  {'gymap compound sas', 'gymap group', 'gymap sas', 'ste gymap'},
#  {'ooo "tsentrum"', 'sia"centrum europa"'},
#  {'bitumix', 'bitumix s.a.'},
#  {'basf petronas chemicals sdn bhd', 'basf rus gmbh'},
#  {'adhesives research, inc.'},
#  {'tuba taban', 'tuba termo kauçuk taban san. ve ti̇c. ltd'},
#  {'ooo"kamimp"'},
#  {'ooo rusplast', 'rusplast, ooo (lobanovo)'},
#  {'georg boerner',
#   'georg borner chemisches werk fur dach- und bautenschutz gmbh & co. kg',
#   'georg börner chemisches werk für dach- und bautenschutz gmbh & co. kg'},
#  {'emulbit', 'emulbit sp. z o.o.'},
#  {'denka company', 'denka kabushiki-gaisha'},
#  {'famos gmbh', 'famos gmbh & co. kg'},
#  {'daramic, llc', 'daramic, llc, zweigniederlassung norderstedt'},
#  {'adams resources exploration corporation, 112 oil and gas assets',
#   'adams resources exploration corporation, oil and gas assets in crocket and irion counties in texas',
#   'adams resources exploration corporation, oil and gas assets outside the permian basin'},
#  {'garland', 'the garland company, inc.'},
#  {'cardiac science corporation', 'cardiac science holdings (uk) limited'},
#  {'cengiz insaat sanayi ve ticaret a s',
#   'cengiz insaat sanayi ve ticaret a.s.',
#   'cengiz i̇nşaat'},
#  {' total oil india private limited,  total',
#   'total oil india limited',
#   'total oil india private limited'},
#  {'bostik', 'bostik nederland b.v.'},
#  {'copernit s.p.a.', 'ooo"kopernit i k"'},
#  {'us ply ', 'us ply inc.'},
#  {'fatih okce sanayi ve ticaret anonim sirketi',
#   'fatih ökçe',
#   'fatih ökçe sanayi ve ticaret a.ş.'},
#  {'hexpol compounding',
#   'hexpol compounding (uk) ltd.',
#   'hexpol compounding llc'},
#  {'vetroasfalto', 'vetroasfalto s.p.a.'},
#  {'epiroc drilling solutions llc', 'ooo"epirok rus"'},
#  {'youngnam spinning', 'youngnam spinning co., ltd.'},
#  {'vedag gmbh', 'vedag gmbh\xa0'},
#  {'copernit ag', 'copernit spa'},
#  {'kraton', 'kraton polymers '},
#  {'ooo "takata rus"', 'takata ag"'},
#  {'parker kawakami', 'parker kawakami co., ltd.'},
#  {'mct gmbh & co. kg',
#   'mct misch & compoundier technik gmbh',
#   'mct misch + compoundiertechnik gmbh & co kg'},
#  {'safic alcan group', 'safic alcan italia sp a'},
#  {'dow corning (0178) cdw', 'dow corning india pvt., ltd.'},
#  {'esha', 'esha strasse gmbh'},
#  {'hikari glass (h.k.) limited', 'hikari glass co ltd'},
#  {'ergon asphalt', 'ergon asphalt & emulsions, inc.'},
#  {'eastland compounders', 'eastland compounding'},
#  {'bostik gmbh',
#   'bostik inc',
#   'bostik sa',
#   'bostik sp.z.o.o.',
#   'ooo "bostik"'},
#  {'servicom (off-spec)', 'servicom s.a. (bvmt:servi) - سرفيكوم'},
#  {'ooo "zika"', 'sika supply center ag"'},
#  {'oao "severomorskij al\'jans"',
#   'rossijskie morskie suda m-0251"nortern enterprajs i m-0344"morskoj briz oao"severomorskij al\'jans"'},
#  {'hempro a.d. (belex:hmbg)', 'izobit (hempro)'},
#  {'ooo"lo trejd"'},
#  {'forbo siegling gmbh', 'ooo"forbo sigling sng"'},
#  {'red avenue new materials group co., ltd (彤程新材料集团股份有限公司)',
#   'red avenue new materials group co., ltd. (shse:603650)'},
#  {'krones ag', 'ooo "krones"'},
#  {'clopay',
#   'clopay building products',
#   'clopay building products company, inc.'},
#  {'biesterfeld international gmb h', 'biesterfeld simko distribuicao sa'},
#  {'safic alcan', 'safic-alcan polska sp. z o.o.'},
#  {'helios kemostik tovarna lepil in kemicnih izdelkov, d.o.o',
#   'ooo "helios rus"'},
#  {'vaparoid', 'vaparoid ag'},
#  {'alan l grant', 'alan l grant polymer inc.'},
#  {'t.l. squire', 't.l. squire & co. inc.'},
#  {'manitou bf', 'ooo "manitu vostok"'},
#  {'ooo"peri"', 'peri gmbh'},
#  {'ooo "huskvarna"'},
#  {'asfaltos chova ', 'asfaltos chova sa'},
#  {'bitoumina s.a.', 'bitoumina sa'},
#  {'ooo"dom odezhdy"'},
#  {'izolacja-matizol sa przedsiębiorstwo materiałów izolacyjnych',
#   'pmi izolacja matizol s.a.',
#   'selena (izolacja matizol)'},
#  {'p.b.m. polimer bitumen modifiers di leonardo baccarelli e c. sas',
#   'pbm (bacarelli)'},
#  {'armacell poland sp. z.o.o"', 'ooo "armasell\'"'},
#  {'baxter s.a.', 'zao kompanija "bakster"'},
#  {'ajkhoff bergbautehnik gmbh', 'ooo"ajkhoff sibir\'"'},
#  {'vestas wind technology (china) co., ltd.',
#   'vestas wind technology india private ltd.'},
#  {'oü pigipada', 'pigipada limited liability company', 'pigipada oü'},
#  {'calzaturificio franceschetti s.r.l.', 'franchescetti '},
#  {'malarkey', 'malarkey roofing products', 'malarkey roofing products co.'},
#  {'ditecpesa', 'ditecpesa s.a.'},
#  {'ooo"artsana rus"'},
#  {'avery denisson (be)', 'avery dennison kunshan co., ltd.'},
#  {'parker hannifin industria e comercio ltda',
#   'parker hannifin industries e com ltda'},
#  {'stemaco', 'stemaco usa'},
#  {'dragon poland', 'dragon poland sp. z o.o. sp.k.'},
#  {'izobud', 'izobud group of companies'},
#  {'asphalt, tar and bitumen', 'plastisavio s.p.a'},
#  {'kleiberit', 'kleiberit chimie sarl'},
#  {'dana', 'dana industrias ltda'},
#  {'petrotekno', 'petrotekno, s.a. de c.v.'},
#  {'asia pharm pack',
#   "obschestvo s ogranichennoj otvetstvennost'ju asia pharm pack"},
#  {'cardinal s.r.l.', 'cardinal srl'},
#  {'basf cenrtal asia llp', 'basf central asia llp'},
#  {'leman usa', 'leman usa. atlanta'},
#  {'ooo "vintershtajger"', 'wintersteiger ag'},
#  {'aspa', 'aspa gmbh'},
#  {'conveyor rollers (bridge) limited', 'kv rollers'},
#  {'amol plastic leetkooh co, ltd', 'amolplastic leetkooh co.'},
#  {'lindner aktiengesellschaft', 'ooo"lindner"'},
#  {'rasco bitumentechnic gmbh', 'rasco bitumentechnik gmbh'},
#  {'chevron phillips chemical co. lp', 'phillips tuftex ltd.'},
#  {'ooo "mediainvest"', 'ooo"mediainvest"'},
#  {'hexpol', 'hexpol ab (publ) (om:hpol b)'},
#  {'china national petroleum waterproof',
#   'china national petroleum waterproof (shenzhen) co.,ltd. '},
#  {'exel logistics inc.', 'exel logistics warehouse'},
#  {'recron (malaysia) sdn bhd', 'recron (malaysia) sdn.bhd.'},
#  {'ziylan taban san.tic.a.s.',
#   'ziylan taban sanayii ve ticaret anonim sirketi',
#   'zi̇ylan taban'},
#  {'cobalt holdings', 'cobalt holdings, llc'},
#  {'casali', 'casali spa'},
#  {'follmann chemie gmbh', 'ooo"fol\'mann"'},
#  {'izolacja - jarocin spółka akcyjna', 'izolacja jarocin'},
#  {'agilent technologies mfg gmbh & shipping department',
#   'ooo "adzhilent teknolodzhiz"'},
#  {'kvk', 'kvk corporation', 'kvk corporation (jasdaq:6484)'},
#  {'bosch thermotechnik gmbh', 'ooo "bosh termotehnika"'},
#  {'blufixx', 'blufixx gmbh'},
#  {'marangoni retreading systems deutschland',
#   'marangoni retreading systems deutschland gmbh '},
#  {'kawasaki heavy industries, ltd.', 'ooo"kavasaki gaz turbin servis rus"'},
#  {'ooo"simens tehnologii gazovyh turbin"', 'siemens aktiengesellschaft'},
#  {'hilti aktiengesellschaft', 'zao "hilti distrib\'jushn ltd"'},
#  {'abena international a/s', 'ooo"abena"'},
#  {'achem technology (dongguan)',
#   'achem technology corp.',
#   'achem technology dongguan'},
#  {'ao"tetra pak"', 'tetra pak international sa'},
#  {'termoprene polymers', 'thermoprene, inc.'},
#  {'bazalt group (dortmunder gussasphalt gmbh & co. kg, dga)',
#   'dortmunder gussasphalt gmbh & co. kg'},
#  {'continental matador rubber, s.r.o. ', 'kontinental matador trak taerz sro'},
#  {'tecnofilm', 'tecnofilm spa'},
#  {'indian synthetic rubber ltd', 'isrl'},
#  {'ooo"el keramika"'},
#  {' contitech transportbandsysteme gmbh', 'contitech thermopol inc.'},
#  {'ooo"olimp"'},
#  {'maneki japan co., limited', 'ooo"maneki-rus"'},
#  {'polyone', 'polyone corporation (nyse:pol)'},
#  {'dsv air & sea inc.', 'dsv air & sea s.a. de c.v.'},
#  {'bitbau', 'bitbau dörr', 'bitbau dörr gmbh'},
#  {'valley asphalt', 'valley asphalt corp.'},
#  {"emam asfal'tos", 'emam asfaltos'},
#  {'cabopol', 'cabopol - polymer compounds, s.a'},
#  {'crafco', 'crafco, inc.'},
#  {'ooo"perel rasha"', 'perel oy'},
#  {'pikasan plastik kauçuk sanayi a.ş.', 'pi̇kasan'},
#  {'next retail limited', 'ooo"nekst"'},
#  {'double coin', 'double coin holding'},
#  {'werner janikowo', 'werner janikowo sp z o o'},
#  {'ooo"impeks"'},
#  {'mapei s.p.a.', 'zao "mapei"'},
#  {'bolton adhesives', 'bolton adhesives b.v.'},
#  {'ooo"gelaksi kargo servis"'},
#  {'ooo"skf tver\'"', 'skf lubrication systems germany gmbh'},
#  {'sherwin-williams ', 'the sherwin-williams company (nyse:shw)'},
#  {'shenzhen comlink electronic', 'shenzhen comlink electronics co., ltd.'},
#  {'hira industries l.l.c.', 'hira middle east'},
#  {'aps', 'aps paving stone inc', 'aps paving&stone inc'},
#  {'lusocopla', 'lusocopla - fábrica de colas industriais, lda'},
#  {'inreco', 'inreco a/s'},
#  {'toray carbon fibers america, inc.', 'toray carbon fibers europe s.a.'},
#  {'filial kompanii "sahalin enerdzhi investment kompani ltd."',
#   'sakhalin energy investment co. ltd'},
#  {'a. westensee & partner rohstoff gmbh', 'awp-rohstoffe'},
#  {'fourny', 'fourny nv'},
#  {'lion copolymer holdings llc', 'lion elastomers, llc'},
#  {'warden asphalt', 'warden asphalt co.'},
#  {'ao "rotofleks"', 'rotoflex ag'},
#  {'helm ag', 'helm u.s. corporation'},
#  {'danosa', 'danosa france'},
#  {'ooo"ortgraf"'},
#  {'braas gmbh', 'ooo "braas-dsk 1"'},
#  {'panda logistics usa inc.', 'panda logistics usa inc. (new york)'},
#  {'ooo "k\'ju ekspress"'},
#  {'m. holland co. ccp', 'm.holland co. ccp'},
#  {'jiangsu baoli international',
#   'jiangsu baoli international investment co., ltd. (szse:300135)'},
#  {'dukt', 'dukt sp. z o.o.'},
#  {'ooo "manders"'},
#  {'puma energy espana', 'puma energy international b.v'},
#  {'ooo"novyj mir"'}]
